# %% [markdown]
# # Notebook to segment GeoTIFF Sentinel-2 Satellite Images into 256*256 chunks
# ## Image segmentation is performed so that the file type and its quality remain
# ### First we will pair the before and after images images to only segment the images of an entire pair
# #### Authenticate to Google Drive to access the files

# %%
import io
import rasterio
import os
import numpy as np
import tempfile
from rasterio.windows import Window
import rasterio.windows
from rasterio.enums import Resampling
from tifffile import imwrite
from google.oauth2 import service_account
from googleapiclient.discovery import build
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.http import MediaIoBaseDownload, MediaIoBaseUpload

# %%
# OAuth 2.0 credentials (client_secret.json) should be in the same directory as this script
CLIENT_SECRET_FILE = 'client_secrets.json'
API_NAME = 'drive'
API_VERSION = 'v3'

# Create OAuth flow
flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_FILE, ['https://www.googleapis.com/auth/drive'])

# Authenticate and authorize the user
credentials = flow.run_local_server(port=0)

# Create a Drive API client
service = build(API_NAME, API_VERSION, credentials=credentials)

# List files in your Google Drive
results = service.files().list().execute()
files = results.get('files', [])

# Define the folder IDs the images in Google Drive
beforeRGB_folder_id = "1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf"
afterRGB_folder_id = '1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'
beforeMask_folder_id ="1ketMQmPQfPWh0X45fwvmee1DvzfHPSXd"
afterMask_folder_id = "1ky2Jj7s7jnyeVWVwPHEyrYE-mOlsu1oO" 
NDVI_Mask_path = "/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/NDVI_Masks"
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1003083568572-78avuh89fu558ciatmapqhgpka9p4c3l.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A51161%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=MhsyF7zxnk8tgC8RJSjZcC3ZL6RYHG&access_type=offline

# %% [markdown]
# ## Pair Before and After images
# ### List the paired files

# %%
# Function to list all files in a folder with their IDs and names
def list_files_in_folder(service, folder_id):
    results = []
    page_token = None

    while True:
        response = service.files().list(
            q=f"'{folder_id}' in parents",
            pageSize=1000,  # Increase if you have more than 1000 files
            pageToken=page_token,
            fields="nextPageToken, files(id, name)"
        ).execute()

        files = response.get('files', [])
        results.extend(files)
        page_token = response.get('nextPageToken')
        if not page_token:
            break

    return results

# List all files in the "before" and "after" folders
before_files = list_files_in_folder(service, beforeRGB_folder_id)
after_files = list_files_in_folder(service, afterRGB_folder_id )

# %% [markdown]
# ### Find matching files based on the common numbers using file IDs

# %%
# Find matching files based on the common numbers using file IDs
matchingRGB_files = {}

for before_file in before_files:
    before_filename = before_file['name']
    if before_filename.startswith("RGB_BeforeFire"):
        # Extract the number from the filename
        num = before_filename.split("RGB_BeforeFire")[1].split(".tif")[0]

        # Construct the corresponding "after" filename
        after_filename = f"RGB_AfterFire{num}.tif"

        # Search for the "after" file by name in the list of "after" files
        for after_file in after_files:
            if after_file['name'] == after_filename:
                matchingRGB_files[before_file['id']] = after_file['id']
                break
print(len(matchingRGB_files))
# Out:
# 382

# %% [markdown]
# ## Pair the remaining matched Before RGB files with their two-dimensional labels.

# %%
# List all files in the "before" and "after" folders
before_files = list_files_in_folder(service, beforeRGB_folder_id)
beforeMask_files = list_files_in_folder(service, beforeMask_folder_id)

# Create lists to store the file names for both folders
before_filenames = [file['name'] for file in before_files]
beforeMask_filenames = [file['name'] for file in beforeMask_files]

# %%
matchingMask_files = {}

for before_file_id, after_file_id in matchingRGB_files.items():
    # Extract the number from the BeforeRGB filename
    before_filename = service.files().get(fileId=before_file_id, fields="name").execute()['name']
    num = before_filename.split("RGB_BeforeFire")[1].split(".tif")[0]

    # Construct the corresponding mask filename
    before_mask_filename = f"RGB_BeforeFire{num}_with_mask.tif"

    # Search for the corresponding mask file by name in the list of mask files
    for before_mask_file in  beforeMask_files:
        if before_mask_file['name'] == before_mask_filename:
            matchingMask_files[before_file_id] = before_mask_file['id']

print("Matching Mask files:", len(matchingMask_files))
# Out:
# Matching Mask files: 382

# %% [markdown]
# ## Image Segmentation

# %%
# Define the output folder for BEFORE RGB tiles 
outputRGB_folder = '/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/BeforeRGBSegments'

# Define the output folder for BEFORE two-dimensional labels 
outputMask_folder = '/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/BeforeMaskSegments'

tile_size =256

# %% [markdown]
# ### Segment the Before GeoTIFF files
# #### Temporarily download the images to segment it

# %%
# Function to download a file from Google Drive
def download_file_from_drive(service, file_id, local_filename):
    request = service.files().get_media(fileId=file_id)
    fh = io.FileIO(local_filename, 'wb')
    downloader = MediaIoBaseDownload(fh, request)
    
    done = False
    while not done:
        status, done = downloader.next_chunk()
    
    fh.close()
    return local_filename

# %% [markdown]
# ## Save the segments without changing the data
# ### To do this rasterio and tifffile packages need to be used together

# %%
# Function to save image tiles without changing the data type
def save_rgb_tiles(image_path, output_folder, tile_size, parent_name):
    with rasterio.open(image_path) as src:
        height = src.height
        width = src.width

        num_rows = height // tile_size
        num_cols = width // tile_size

        tile_counter = 1  # Initialize the tile counter

        for i in range(num_rows):
            for j in range(num_cols):
                window = Window(j * tile_size, i * tile_size, tile_size, tile_size)
                
                # Read the original data without modifications
                tile = src.read((1, 2, 3), window=window)  # Assuming band order B4, B3, B2

                tile_name = f"{parent_name}_tile_{tile_counter}.tif"
                tile_path = os.path.join(output_folder, tile_name)

                # Save the tile using tifffile without changing data type
                imwrite(tile_path, tile)

                # Update metadata with georeferencing information
                meta = src.meta.copy()
                transform = src.window_transform(window)
                meta.update({
                    'width': tile_size,
                    'height': tile_size,
                    'transform': transform
                })

                with rasterio.open(tile_path, 'w', **meta) as dst:
                    dst.write(tile)

                tile_counter += 1  # Increment the tile counter

# %% [markdown]
# #### Segment the Before RGB images

# %%
# Process each matching pair
for rgb_file_id, mask_file_id in matchingMask_files.items():
    # Find the matching RGB file
    rgb_file = next(file for file in before_files if file['id'] == rgb_file_id)

    # Extract the parent file name (e.g., "RGB_BeforeFire{num}")
    parent_name = os.path.splitext(rgb_file['name'])[0]
    
    print(f"Processing parent image: {parent_name}")
    # Download RGB image
    rgb_temp_file = download_file_from_drive(service, rgb_file_id, tempfile.NamedTemporaryFile(delete=False).name)

    # Segment RGB image into tiles
    save_rgb_tiles(rgb_temp_file, outputRGB_folder, tile_size, parent_name)
    
    # Get the final number of tiles
    final_num_tiles = len([f for f in os.listdir(outputRGB_folder) if f.startswith(f"{parent_name}_tile_")])
    print(f"Final number of tiles for {parent_name}: {final_num_tiles}")

    # Clean up temporary file
    os.remove(rgb_temp_file)
    
     print(f' Tiling of {parent_name} completed succesfully')

# %% [markdown]
# #### Segment the Before two-dimensional labels

# %%
def save_label_mask_tiles(mask_path, output_folder, tile_size, parent_name):
    with rasterio.open(mask_path) as src:
        height = src.height
        width = src.width

        num_rows = height // tile_size
        num_cols = width // tile_size

        tile_counter = 1  # Initialize the tile counter

        for i in range(num_rows):
            for j in range(num_cols):
                window = Window(j * tile_size, i * tile_size, tile_size, tile_size)
                
                # Read the original data without modifications
                mask_tile = src.read(1, window=window)

                tile_name = f"{parent_name}_tile_{tile_counter}.tif"
                tile_path = os.path.join(output_folder, tile_name)

                # Save the two-dimensional label using tifffile without changing data type
                imwrite(tile_path, mask_tile)

                tile_counter += 1  # Increment the tile counter

# %%
# Process each matching pair
for rgb_file_id, mask_file_id in matchingMask_files.items():
    # Find the matching two-dimensional label
    mask_file = next(file for file in beforeMask_files if file['id'] == mask_file_id)

    # Extract the parent file name (e.g., "RGB_AfterFire{num}")
    parent_name = os.path.splitext(mask_file['name'])[0]
    
    print(f"Processing parent image: {parent_name}")
    
    # Define the output folder for BEFORE two-dimensional labels
    outputMask_folder = '/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/BeforeMaskSegments'
    
    
    # Download the two-dimensional label to a temporary file
    mask_temp_file_path = os.path.join(tempfile.gettempdir(), f"{parent_name}_temp_mask.tif")
    mask_temp_file = download_file_from_drive(service, mask_file_id, mask_temp_file_path)

    print(f"Downloaded mask file to: {mask_temp_file}")

    # Segment RGB image into tiles
    save_label_mask_tiles(mask_temp_file, outputMask_folder, tile_size, parent_name)
    
    # Get the final number of tiles
    final_num_tiles = len([f for f in os.listdir(outputMask_folder) if f.startswith(f"{parent_name}_tile_")])
    print(f"Final number of tiles for {parent_name}: {final_num_tiles}")

    # Clean up temporary file
    os.remove(mask_temp_file)

print(f'Tiling completed successfully')

# %% [markdown]
# ## Pair after images

# %%
# Define the output folder for AFTER RGB tiles 
outputAfterRGB_folder = '/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/AfterRGBSegments'

# Define the output folder for AFTER two-dimensional labels 
outputAfterMask_folder = '/Volumes/HD710PRO/Fire_and_Hurricane_Images/Fire/AfterMaskSegments'
 
tile_size =256

# %%
# List all files in the "after" masks folder
afterMask_files = list_files_in_folder(service, afterMask_folder_id)
after_files_dict = {file['id']: file for file in after_files}

# Create a dictionary to store pairs of "after" RGB IDs and their corresponding mask IDs
matchingAfterMask_files = {}

# Iterate through matchingRGB_files and find corresponding two-dimensional labels
for before_id, after_id in matchingRGB_files.items():
    # Extract the number from the "after" filename
    num = after_files_dict[after_id]['name'].split("RGB_AfterFire")[1].split(".tif")[0]

    # Construct the "after" two-dimensional label filename
    afterMask_filename = f"RGB_AfterFire{num}_with_mask.tif"

    # Search for the "after" two-dimensional file by name in the list of "after" mask files
    for afterMask_file in afterMask_files:
        if afterMask_file['name'] == afterMask_filename:
            matchingAfterMask_files[after_id] = afterMask_file['id']  # Store file ID instead of file name
            break

# Print the number of matching "after" RGB and mask files
print(len(matchingAfterMask_files))
# Out:
# 382

# %% [markdown]
# #### Segment the After RGB images

# %%
after_files = list_files_in_folder(service, afterRGB_folder_id)

# Sort the files to ensure consistent order
after_files.sort(key=lambda x: x['name'])

# Process each matching pair starting from index 320 because segmenting process was stopped before
start_index = 320
matching_files_to_process = list(matchingAfterMask_files.items())[start_index:]

for AfterRgb_file_id, AfterMask_file_id in matching_files_to_process:
    # Find the matching RGB file
    AfterRGB_file = next(file for file in after_files if file['id'] == AfterRgb_file_id)

    # Extract the parent file name (e.g., "RGB_AfterFire{num}")
    parent_name = os.path.splitext(AfterRGB_file['name'])[0]
    
    print(f"Processing parent image: {parent_name}")
    # Download RGB image
    rgb_temp_file = download_file_from_drive(service, AfterRgb_file_id, tempfile.NamedTemporaryFile(delete=False).name)

    # Segment RGB image into tiles
    save_rgb_tiles(rgb_temp_file, outputAfterRGB_folder, tile_size, parent_name)
    
    # Get the final number of tiles
    final_num_tiles = len([f for f in os.listdir(outputAfterRGB_folder) if f.startswith(f"{parent_name}_tile_")])
    print(f"Final number of tiles for {parent_name}: {final_num_tiles}")

    # Clean up temporary file
    os.remove(rgb_temp_file)
    
    print(f'Tiling of {parent_name} completed successfully')
# Out:
# Processing parent image: RGB_AfterFire179
# Final number of tiles for RGB_AfterFire179: 208
# Tiling of RGB_AfterFire179 completed successfully
# Processing parent image: RGB_AfterFire178
# Final number of tiles for RGB_AfterFire178: 208
# Tiling of RGB_AfterFire178 completed successfully
# Processing parent image: RGB_AfterFire164
# Final number of tiles for RGB_AfterFire164: 221
# Tiling of RGB_AfterFire164 completed successfully
# Processing parent image: RGB_AfterFire161
# Final number of tiles for RGB_AfterFire161: 208
# Tiling of RGB_AfterFire161 completed successfully
# Processing parent image: RGB_AfterFire160
# Final number of tiles for RGB_AfterFire160: 221
# Tiling of RGB_AfterFire160 completed successfully
# Processing parent image: RGB_AfterFire152
# Final number of tiles for RGB_AfterFire152: 208
# Tiling of RGB_AfterFire152 completed successfully
# Processing parent image: RGB_AfterFire151
# Final number of tiles for RGB_AfterFire151: 221
# Tiling of RGB_AfterFire151 completed successfully
# Processing parent image: RGB_AfterFire145
# Final number of tiles for RGB_AfterFire145: 221
# Tiling of RGB_AfterFire145 completed successfully
# Processing parent image: RGB_AfterFire144
# Final number of tiles for RGB_AfterFire144: 208
# Tiling of RGB_AfterFire144 completed successfully
# Processing parent image: RGB_AfterFire143
# Final number of tiles for RGB_AfterFire143: 208
# Tiling of RGB_AfterFire143 completed successfully
# Processing parent image: RGB_AfterFire141
# Final number of tiles for RGB_AfterFire141: 208
# Tiling of RGB_AfterFire141 completed successfully
# Processing parent image: RGB_AfterFire135
# Final number of tiles for RGB_AfterFire135: 208
# Tiling of RGB_AfterFire135 completed successfully
# Processing parent image: RGB_AfterFire133
# Final number of tiles for RGB_AfterFire133: 208
# Tiling of RGB_AfterFire133 completed successfully
# Processing parent image: RGB_AfterFire130
# Final number of tiles for RGB_AfterFire130: 221
# Tiling of RGB_AfterFire130 completed successfully
# Processing parent image: RGB_AfterFire126
# Final number of tiles for RGB_AfterFire126: 221
# Tiling of RGB_AfterFire126 completed successfully
# Processing parent image: RGB_AfterFire125
# Final number of tiles for RGB_AfterFire125: 208
# Tiling of RGB_AfterFire125 completed successfully
# Processing parent image: RGB_AfterFire123
# Final number of tiles for RGB_AfterFire123: 221
# Tiling of RGB_AfterFire123 completed successfully
# Processing parent image: RGB_AfterFire122
# Final number of tiles for RGB_AfterFire122: 221
# Tiling of RGB_AfterFire122 completed successfully
# Processing parent image: RGB_AfterFire118
# Final number of tiles for RGB_AfterFire118: 221
# Tiling of RGB_AfterFire118 completed successfully
# Processing parent image: RGB_AfterFire117
# Final number of tiles for RGB_AfterFire117: 221
# Tiling of RGB_AfterFire117 completed successfully
# Processing parent image: RGB_AfterFire116
# Final number of tiles for RGB_AfterFire116: 208
# Tiling of RGB_AfterFire116 completed successfully
# Processing parent image: RGB_AfterFire115
# Final number of tiles for RGB_AfterFire115: 208
# Tiling of RGB_AfterFire115 completed successfully
# Processing parent image: RGB_AfterFire112
# Final number of tiles for RGB_AfterFire112: 208
# Tiling of RGB_AfterFire112 completed successfully
# Processing parent image: RGB_AfterFire48
# Final number of tiles for RGB_AfterFire48: 221
# Tiling of RGB_AfterFire48 completed successfully
# Processing parent image: RGB_AfterFire47
# Final number of tiles for RGB_AfterFire47: 221
# Tiling of RGB_AfterFire47 completed successfully
# Processing parent image: RGB_AfterFire46
# Final number of tiles for RGB_AfterFire46: 208
# Tiling of RGB_AfterFire46 completed successfully
# Processing parent image: RGB_AfterFire44
# Final number of tiles for RGB_AfterFire44: 208
# Tiling of RGB_AfterFire44 completed successfully
# Processing parent image: RGB_AfterFire43
# Final number of tiles for RGB_AfterFire43: 208
# Tiling of RGB_AfterFire43 completed successfully
# Processing parent image: RGB_AfterFire42
# Final number of tiles for RGB_AfterFire42: 221
# Tiling of RGB_AfterFire42 completed successfully
# Processing parent image: RGB_AfterFire39
# Final number of tiles for RGB_AfterFire39: 221
# Tiling of RGB_AfterFire39 completed successfully
# Processing parent image: RGB_AfterFire37
# Final number of tiles for RGB_AfterFire37: 221
# Tiling of RGB_AfterFire37 completed successfully
# Processing parent image: RGB_AfterFire36
# Final number of tiles for RGB_AfterFire36: 221
# Tiling of RGB_AfterFire36 completed successfully
# Processing parent image: RGB_AfterFire35
# Final number of tiles for RGB_AfterFire35: 221
# Tiling of RGB_AfterFire35 completed successfully
# Processing parent image: RGB_AfterFire33
# Final number of tiles for RGB_AfterFire33: 208
# Tiling of RGB_AfterFire33 completed successfully
# Processing parent image: RGB_AfterFire32
# Final number of tiles for RGB_AfterFire32: 221
# Tiling of RGB_AfterFire32 completed successfully
# Processing parent image: RGB_AfterFire30
# Final number of tiles for RGB_AfterFire30: 208
# Tiling of RGB_AfterFire30 completed successfully
# Processing parent image: RGB_AfterFire29
# Final number of tiles for RGB_AfterFire29: 208
# Tiling of RGB_AfterFire29 completed successfully
# Processing parent image: RGB_AfterFire28
# Final number of tiles for RGB_AfterFire28: 208
# Tiling of RGB_AfterFire28 completed successfully
# Processing parent image: RGB_AfterFire27
# Final number of tiles for RGB_AfterFire27: 208
# Tiling of RGB_AfterFire27 completed successfully
# Processing parent image: RGB_AfterFire26
# Final number of tiles for RGB_AfterFire26: 208
# Tiling of RGB_AfterFire26 completed successfully
# Processing parent image: RGB_AfterFire25
# Final number of tiles for RGB_AfterFire25: 208
# Tiling of RGB_AfterFire25 completed successfully
# Processing parent image: RGB_AfterFire23
# Final number of tiles for RGB_AfterFire23: 221
# Tiling of RGB_AfterFire23 completed successfully
# Processing parent image: RGB_AfterFire22
# Final number of tiles for RGB_AfterFire22: 221
# Tiling of RGB_AfterFire22 completed successfully
# Processing parent image: RGB_AfterFire21
# Final number of tiles for RGB_AfterFire21: 221
# Tiling of RGB_AfterFire21 completed successfully
# Processing parent image: RGB_AfterFire20
# Final number of tiles for RGB_AfterFire20: 221
# Tiling of RGB_AfterFire20 completed successfully
# Processing parent image: RGB_AfterFire19
# Final number of tiles for RGB_AfterFire19: 221
# Tiling of RGB_AfterFire19 completed successfully
# Processing parent image: RGB_AfterFire18
# Final number of tiles for RGB_AfterFire18: 221
# Tiling of RGB_AfterFire18 completed successfully
# Processing parent image: RGB_AfterFire17
# Final number of tiles for RGB_AfterFire17: 221
# Tiling of RGB_AfterFire17 completed successfully
# Processing parent image: RGB_AfterFire16
# Final number of tiles for RGB_AfterFire16: 221
# Tiling of RGB_AfterFire16 completed successfully
# Processing parent image: RGB_AfterFire15
# Final number of tiles for RGB_AfterFire15: 208
# Tiling of RGB_AfterFire15 completed successfully
# Processing parent image: RGB_AfterFire14
# Final number of tiles for RGB_AfterFire14: 221
# Tiling of RGB_AfterFire14 completed successfully
# Processing parent image: RGB_AfterFire13
# Final number of tiles for RGB_AfterFire13: 221
# Tiling of RGB_AfterFire13 completed successfully
# Processing parent image: RGB_AfterFire11
# Final number of tiles for RGB_AfterFire11: 208
# Tiling of RGB_AfterFire11 completed successfully
# Processing parent image: RGB_AfterFire10
# Final number of tiles for RGB_AfterFire10: 221
# Tiling of RGB_AfterFire10 completed successfully
# Processing parent image: RGB_AfterFire9
# Final number of tiles for RGB_AfterFire9: 208
# Tiling of RGB_AfterFire9 completed successfully
# Processing parent image: RGB_AfterFire8
# Final number of tiles for RGB_AfterFire8: 221
# Tiling of RGB_AfterFire8 completed successfully
# Processing parent image: RGB_AfterFire7
# Final number of tiles for RGB_AfterFire7: 208
# Tiling of RGB_AfterFire7 completed successfully
# Processing parent image: RGB_AfterFire6
# Final number of tiles for RGB_AfterFire6: 208
# Tiling of RGB_AfterFire6 completed successfully
# Processing parent image: RGB_AfterFire5
# Final number of tiles for RGB_AfterFire5: 208
# Tiling of RGB_AfterFire5 completed successfully
# Processing parent image: RGB_AfterFire4
# Final number of tiles for RGB_AfterFire4: 221
# Tiling of RGB_AfterFire4 completed successfully
# Processing parent image: RGB_AfterFire2
# Final number of tiles for RGB_AfterFire2: 221
# Tiling of RGB_AfterFire2 completed successfully
# Processing parent image: RGB_AfterFire1
# Final number of tiles for RGB_AfterFire1: 221
# Tiling of RGB_AfterFire1 completed successfully

# %% [markdown]
# #### Segment the After Two-dimensional labels

# %%
# Process each matching pair
for rgb_file_id, mask_file_id in matchingAfterMask_files.items():
    # Find the matching RGB file
    mask_file = next(file for file in afterMask_files if file['id'] == mask_file_id)

    # Extract the parent file name (e.g., "RGB_AfterFire{num}")
    parent_name = os.path.splitext(mask_file['name'])[0]
    
    print(f"Processing parent image: {parent_name}")
    # Download RGB image
    mask_temp_file = download_file_from_drive(service, mask_file_id, tempfile.NamedTemporaryFile(delete=False).name)

    # Segment RGB image into tiles
    save_label_mask_tiles(mask_temp_file, outputAfterMask_folder, tile_size, parent_name)
    
    # Get the final number of tiles
    final_num_tiles = len([f for f in os.listdir(outputAfterMask_folder) if f.startswith(f"{parent_name}_tile_")])
    print(f"Final number of tiles for {parent_name}: {final_num_tiles}")

    # Clean up temporary file
    os.remove(mask_temp_file)
    
    print(f' Tiling of {parent_name} completed succesfully')
# Out:
# Processing parent image: RGB_AfterFire713_with_mask
# Final number of tiles for RGB_AfterFire713_with_mask: 208
#  Tiling of RGB_AfterFire713_with_mask completed succesfully
# Processing parent image: RGB_AfterFire712_with_mask
# Final number of tiles for RGB_AfterFire712_with_mask: 221
#  Tiling of RGB_AfterFire712_with_mask completed succesfully
# Processing parent image: RGB_AfterFire711_with_mask
# Final number of tiles for RGB_AfterFire711_with_mask: 221
#  Tiling of RGB_AfterFire711_with_mask completed succesfully
# Processing parent image: RGB_AfterFire710_with_mask
# Final number of tiles for RGB_AfterFire710_with_mask: 221
#  Tiling of RGB_AfterFire710_with_mask completed succesfully
# Processing parent image: RGB_AfterFire708_with_mask
# Final number of tiles for RGB_AfterFire708_with_mask: 208
#  Tiling of RGB_AfterFire708_with_mask completed succesfully
# Processing parent image: RGB_AfterFire706_with_mask
# Final number of tiles for RGB_AfterFire706_with_mask: 221
#  Tiling of RGB_AfterFire706_with_mask completed succesfully
# Processing parent image: RGB_AfterFire705_with_mask
# Final number of tiles for RGB_AfterFire705_with_mask: 221
#  Tiling of RGB_AfterFire705_with_mask completed succesfully
# Processing parent image: RGB_AfterFire704_with_mask
# Final number of tiles for RGB_AfterFire704_with_mask: 208
#  Tiling of RGB_AfterFire704_with_mask completed succesfully
# Processing parent image: RGB_AfterFire703_with_mask
# Final number of tiles for RGB_AfterFire703_with_mask: 221
#  Tiling of RGB_AfterFire703_with_mask completed succesfully
# Processing parent image: RGB_AfterFire701_with_mask
# Final number of tiles for RGB_AfterFire701_with_mask: 208
#  Tiling of RGB_AfterFire701_with_mask completed succesfully
# Processing parent image: RGB_AfterFire699_with_mask
# Final number of tiles for RGB_AfterFire699_with_mask: 221
#  Tiling of RGB_AfterFire699_with_mask completed succesfully
# Processing parent image: RGB_AfterFire698_with_mask
# Final number of tiles for RGB_AfterFire698_with_mask: 221
#  Tiling of RGB_AfterFire698_with_mask completed succesfully
# Processing parent image: RGB_AfterFire696_with_mask
# Final number of tiles for RGB_AfterFire696_with_mask: 208
#  Tiling of RGB_AfterFire696_with_mask completed succesfully
# Processing parent image: RGB_AfterFire695_with_mask
# Final number of tiles for RGB_AfterFire695_with_mask: 221
#  Tiling of RGB_AfterFire695_with_mask completed succesfully
# Processing parent image: RGB_AfterFire694_with_mask
# Final number of tiles for RGB_AfterFire694_with_mask: 221
#  Tiling of RGB_AfterFire694_with_mask completed succesfully
# Processing parent image: RGB_AfterFire692_with_mask
# Final number of tiles for RGB_AfterFire692_with_mask: 208
#  Tiling of RGB_AfterFire692_with_mask completed succesfully
# Processing parent image: RGB_AfterFire690_with_mask
# Final number of tiles for RGB_AfterFire690_with_mask: 208
#  Tiling of RGB_AfterFire690_with_mask completed succesfully
# Processing parent image: RGB_AfterFire688_with_mask
# Final number of tiles for RGB_AfterFire688_with_mask: 208
#  Tiling of RGB_AfterFire688_with_mask completed succesfully
# Processing parent image: RGB_AfterFire687_with_mask
# Final number of tiles for RGB_AfterFire687_with_mask: 221
#  Tiling of RGB_AfterFire687_with_mask completed succesfully
# Processing parent image: RGB_AfterFire686_with_mask
# Final number of tiles for RGB_AfterFire686_with_mask: 208
#  Tiling of RGB_AfterFire686_with_mask completed succesfully
# Processing parent image: RGB_AfterFire684_with_mask
# Final number of tiles for RGB_AfterFire684_with_mask: 208
#  Tiling of RGB_AfterFire684_with_mask completed succesfully
# Processing parent image: RGB_AfterFire683_with_mask
# Final number of tiles for RGB_AfterFire683_with_mask: 208
#  Tiling of RGB_AfterFire683_with_mask completed succesfully
# Processing parent image: RGB_AfterFire682_with_mask
# Final number of tiles for RGB_AfterFire682_with_mask: 221
#  Tiling of RGB_AfterFire682_with_mask completed succesfully
# Processing parent image: RGB_AfterFire681_with_mask
# Final number of tiles for RGB_AfterFire681_with_mask: 221
#  Tiling of RGB_AfterFire681_with_mask completed succesfully
# Processing parent image: RGB_AfterFire680_with_mask
# Final number of tiles for RGB_AfterFire680_with_mask: 221
#  Tiling of RGB_AfterFire680_with_mask completed succesfully
# Processing parent image: RGB_AfterFire679_with_mask
# Final number of tiles for RGB_AfterFire679_with_mask: 221
#  Tiling of RGB_AfterFire679_with_mask completed succesfully
# Processing parent image: RGB_AfterFire677_with_mask
# Final number of tiles for RGB_AfterFire677_with_mask: 221
#  Tiling of RGB_AfterFire677_with_mask completed succesfully
# Processing parent image: RGB_AfterFire676_with_mask
# Final number of tiles for RGB_AfterFire676_with_mask: 208
#  Tiling of RGB_AfterFire676_with_mask completed succesfully
# Processing parent image: RGB_AfterFire674_with_mask
# Final number of tiles for RGB_AfterFire674_with_mask: 221
#  Tiling of RGB_AfterFire674_with_mask completed succesfully
# Processing parent image: RGB_AfterFire673_with_mask
# Final number of tiles for RGB_AfterFire673_with_mask: 208
#  Tiling of RGB_AfterFire673_with_mask completed succesfully
# Processing parent image: RGB_AfterFire671_with_mask
# Final number of tiles for RGB_AfterFire671_with_mask: 208
#  Tiling of RGB_AfterFire671_with_mask completed succesfully
# Processing parent image: RGB_AfterFire669_with_mask
# Final number of tiles for RGB_AfterFire669_with_mask: 221
#  Tiling of RGB_AfterFire669_with_mask completed succesfully
# Processing parent image: RGB_AfterFire668_with_mask
# Final number of tiles for RGB_AfterFire668_with_mask: 221
#  Tiling of RGB_AfterFire668_with_mask completed succesfully
# Processing parent image: RGB_AfterFire667_with_mask
# Final number of tiles for RGB_AfterFire667_with_mask: 221
#  Tiling of RGB_AfterFire667_with_mask completed succesfully
# Processing parent image: RGB_AfterFire666_with_mask
# Final number of tiles for RGB_AfterFire666_with_mask: 221
#  Tiling of RGB_AfterFire666_with_mask completed succesfully
# Processing parent image: RGB_AfterFire665_with_mask
# Final number of tiles for RGB_AfterFire665_with_mask: 208
#  Tiling of RGB_AfterFire665_with_mask completed succesfully
# Processing parent image: RGB_AfterFire664_with_mask
# Final number of tiles for RGB_AfterFire664_with_mask: 208
#  Tiling of RGB_AfterFire664_with_mask completed succesfully
# Processing parent image: RGB_AfterFire663_with_mask
# Final number of tiles for RGB_AfterFire663_with_mask: 208
#  Tiling of RGB_AfterFire663_with_mask completed succesfully
# Processing parent image: RGB_AfterFire662_with_mask
# Final number of tiles for RGB_AfterFire662_with_mask: 221
#  Tiling of RGB_AfterFire662_with_mask completed succesfully
# Processing parent image: RGB_AfterFire661_with_mask
# Final number of tiles for RGB_AfterFire661_with_mask: 208
#  Tiling of RGB_AfterFire661_with_mask completed succesfully
# Processing parent image: RGB_AfterFire660_with_mask
# Final number of tiles for RGB_AfterFire660_with_mask: 221
#  Tiling of RGB_AfterFire660_with_mask completed succesfully
# Processing parent image: RGB_AfterFire659_with_mask
# Final number of tiles for RGB_AfterFire659_with_mask: 221
#  Tiling of RGB_AfterFire659_with_mask completed succesfully
# Processing parent image: RGB_AfterFire657_with_mask
# Final number of tiles for RGB_AfterFire657_with_mask: 208
#  Tiling of RGB_AfterFire657_with_mask completed succesfully
# Processing parent image: RGB_AfterFire656_with_mask
# Final number of tiles for RGB_AfterFire656_with_mask: 221
#  Tiling of RGB_AfterFire656_with_mask completed succesfully
# Processing parent image: RGB_AfterFire655_with_mask
# Final number of tiles for RGB_AfterFire655_with_mask: 221
#  Tiling of RGB_AfterFire655_with_mask completed succesfully
# Processing parent image: RGB_AfterFire654_with_mask
# Final number of tiles for RGB_AfterFire654_with_mask: 208
#  Tiling of RGB_AfterFire654_with_mask completed succesfully
# Processing parent image: RGB_AfterFire652_with_mask
# Final number of tiles for RGB_AfterFire652_with_mask: 208
#  Tiling of RGB_AfterFire652_with_mask completed succesfully
# Processing parent image: RGB_AfterFire651_with_mask
# Final number of tiles for RGB_AfterFire651_with_mask: 221
#  Tiling of RGB_AfterFire651_with_mask completed succesfully
# Processing parent image: RGB_AfterFire650_with_mask
# Final number of tiles for RGB_AfterFire650_with_mask: 234
#  Tiling of RGB_AfterFire650_with_mask completed succesfully
# Processing parent image: RGB_AfterFire649_with_mask
# Final number of tiles for RGB_AfterFire649_with_mask: 208
#  Tiling of RGB_AfterFire649_with_mask completed succesfully
# Processing parent image: RGB_AfterFire648_with_mask
# Final number of tiles for RGB_AfterFire648_with_mask: 221
#  Tiling of RGB_AfterFire648_with_mask completed succesfully
# Processing parent image: RGB_AfterFire647_with_mask
# Final number of tiles for RGB_AfterFire647_with_mask: 208
#  Tiling of RGB_AfterFire647_with_mask completed succesfully
# Processing parent image: RGB_AfterFire646_with_mask
# Final number of tiles for RGB_AfterFire646_with_mask: 208
#  Tiling of RGB_AfterFire646_with_mask completed succesfully
# Processing parent image: RGB_AfterFire645_with_mask
# Final number of tiles for RGB_AfterFire645_with_mask: 208
#  Tiling of RGB_AfterFire645_with_mask completed succesfully
# Processing parent image: RGB_AfterFire644_with_mask
# Final number of tiles for RGB_AfterFire644_with_mask: 208
#  Tiling of RGB_AfterFire644_with_mask completed succesfully
# Processing parent image: RGB_AfterFire643_with_mask
# Final number of tiles for RGB_AfterFire643_with_mask: 208
#  Tiling of RGB_AfterFire643_with_mask completed succesfully
# Processing parent image: RGB_AfterFire642_with_mask
# Final number of tiles for RGB_AfterFire642_with_mask: 221
#  Tiling of RGB_AfterFire642_with_mask completed succesfully
# Processing parent image: RGB_AfterFire640_with_mask
# Final number of tiles for RGB_AfterFire640_with_mask: 208
#  Tiling of RGB_AfterFire640_with_mask completed succesfully
# Processing parent image: RGB_AfterFire639_with_mask
# Final number of tiles for RGB_AfterFire639_with_mask: 221
#  Tiling of RGB_AfterFire639_with_mask completed succesfully
# Processing parent image: RGB_AfterFire638_with_mask
# Final number of tiles for RGB_AfterFire638_with_mask: 208
#  Tiling of RGB_AfterFire638_with_mask completed succesfully
# Processing parent image: RGB_AfterFire637_with_mask
# Final number of tiles for RGB_AfterFire637_with_mask: 221
#  Tiling of RGB_AfterFire637_with_mask completed succesfully
# Processing parent image: RGB_AfterFire636_with_mask
# Final number of tiles for RGB_AfterFire636_with_mask: 221
#  Tiling of RGB_AfterFire636_with_mask completed succesfully
# Processing parent image: RGB_AfterFire635_with_mask
# Final number of tiles for RGB_AfterFire635_with_mask: 208
#  Tiling of RGB_AfterFire635_with_mask completed succesfully
# Processing parent image: RGB_AfterFire634_with_mask
# Final number of tiles for RGB_AfterFire634_with_mask: 208
#  Tiling of RGB_AfterFire634_with_mask completed succesfully
# Processing parent image: RGB_AfterFire633_with_mask
# Final number of tiles for RGB_AfterFire633_with_mask: 221
#  Tiling of RGB_AfterFire633_with_mask completed succesfully
# Processing parent image: RGB_AfterFire632_with_mask
# Final number of tiles for RGB_AfterFire632_with_mask: 208
#  Tiling of RGB_AfterFire632_with_mask completed succesfully
# Processing parent image: RGB_AfterFire631_with_mask
# Final number of tiles for RGB_AfterFire631_with_mask: 221
#  Tiling of RGB_AfterFire631_with_mask completed succesfully
# Processing parent image: RGB_AfterFire630_with_mask
# Final number of tiles for RGB_AfterFire630_with_mask: 221
#  Tiling of RGB_AfterFire630_with_mask completed succesfully
# Processing parent image: RGB_AfterFire629_with_mask
# Final number of tiles for RGB_AfterFire629_with_mask: 221
#  Tiling of RGB_AfterFire629_with_mask completed succesfully
# Processing parent image: RGB_AfterFire628_with_mask
# Final number of tiles for RGB_AfterFire628_with_mask: 221
#  Tiling of RGB_AfterFire628_with_mask completed succesfully
# Processing parent image: RGB_AfterFire627_with_mask
# Final number of tiles for RGB_AfterFire627_with_mask: 221
#  Tiling of RGB_AfterFire627_with_mask completed succesfully
# Processing parent image: RGB_AfterFire626_with_mask
# Final number of tiles for RGB_AfterFire626_with_mask: 221
#  Tiling of RGB_AfterFire626_with_mask completed succesfully
# Processing parent image: RGB_AfterFire625_with_mask
# Final number of tiles for RGB_AfterFire625_with_mask: 208
#  Tiling of RGB_AfterFire625_with_mask completed succesfully
# Processing parent image: RGB_AfterFire624_with_mask
# Final number of tiles for RGB_AfterFire624_with_mask: 221
#  Tiling of RGB_AfterFire624_with_mask completed succesfully
# Processing parent image: RGB_AfterFire623_with_mask
# Final number of tiles for RGB_AfterFire623_with_mask: 208
#  Tiling of RGB_AfterFire623_with_mask completed succesfully
# Processing parent image: RGB_AfterFire622_with_mask
# Final number of tiles for RGB_AfterFire622_with_mask: 221
#  Tiling of RGB_AfterFire622_with_mask completed succesfully
# Processing parent image: RGB_AfterFire621_with_mask
# Final number of tiles for RGB_AfterFire621_with_mask: 221
#  Tiling of RGB_AfterFire621_with_mask completed succesfully
# Processing parent image: RGB_AfterFire620_with_mask
# Final number of tiles for RGB_AfterFire620_with_mask: 221
#  Tiling of RGB_AfterFire620_with_mask completed succesfully
# Processing parent image: RGB_AfterFire619_with_mask
# Final number of tiles for RGB_AfterFire619_with_mask: 195
#  Tiling of RGB_AfterFire619_with_mask completed succesfully
# Processing parent image: RGB_AfterFire617_with_mask
# Final number of tiles for RGB_AfterFire617_with_mask: 208
#  Tiling of RGB_AfterFire617_with_mask completed succesfully
# Processing parent image: RGB_AfterFire616_with_mask
# Final number of tiles for RGB_AfterFire616_with_mask: 208
#  Tiling of RGB_AfterFire616_with_mask completed succesfully
# Processing parent image: RGB_AfterFire615_with_mask
# Final number of tiles for RGB_AfterFire615_with_mask: 221
#  Tiling of RGB_AfterFire615_with_mask completed succesfully
# Processing parent image: RGB_AfterFire614_with_mask
# Final number of tiles for RGB_AfterFire614_with_mask: 208
#  Tiling of RGB_AfterFire614_with_mask completed succesfully
# Processing parent image: RGB_AfterFire613_with_mask
# Final number of tiles for RGB_AfterFire613_with_mask: 221
#  Tiling of RGB_AfterFire613_with_mask completed succesfully
# Processing parent image: RGB_AfterFire612_with_mask
# Final number of tiles for RGB_AfterFire612_with_mask: 221
#  Tiling of RGB_AfterFire612_with_mask completed succesfully
# Processing parent image: RGB_AfterFire611_with_mask
# Final number of tiles for RGB_AfterFire611_with_mask: 221
#  Tiling of RGB_AfterFire611_with_mask completed succesfully
# Processing parent image: RGB_AfterFire610_with_mask
# Final number of tiles for RGB_AfterFire610_with_mask: 208
#  Tiling of RGB_AfterFire610_with_mask completed succesfully
# Processing parent image: RGB_AfterFire590_with_mask
# Final number of tiles for RGB_AfterFire590_with_mask: 221
#  Tiling of RGB_AfterFire590_with_mask completed succesfully
# Processing parent image: RGB_AfterFire589_with_mask
# Final number of tiles for RGB_AfterFire589_with_mask: 221
#  Tiling of RGB_AfterFire589_with_mask completed succesfully
# Processing parent image: RGB_AfterFire588_with_mask
# Final number of tiles for RGB_AfterFire588_with_mask: 221
#  Tiling of RGB_AfterFire588_with_mask completed succesfully
# Processing parent image: RGB_AfterFire587_with_mask
# Final number of tiles for RGB_AfterFire587_with_mask: 221
#  Tiling of RGB_AfterFire587_with_mask completed succesfully
# Processing parent image: RGB_AfterFire586_with_mask
# Final number of tiles for RGB_AfterFire586_with_mask: 208
#  Tiling of RGB_AfterFire586_with_mask completed succesfully
# Processing parent image: RGB_AfterFire585_with_mask
# Final number of tiles for RGB_AfterFire585_with_mask: 221
#  Tiling of RGB_AfterFire585_with_mask completed succesfully
# Processing parent image: RGB_AfterFire584_with_mask
# Final number of tiles for RGB_AfterFire584_with_mask: 221
#  Tiling of RGB_AfterFire584_with_mask completed succesfully
# Processing parent image: RGB_AfterFire583_with_mask
# Final number of tiles for RGB_AfterFire583_with_mask: 221
#  Tiling of RGB_AfterFire583_with_mask completed succesfully
# Processing parent image: RGB_AfterFire582_with_mask
# Final number of tiles for RGB_AfterFire582_with_mask: 221
#  Tiling of RGB_AfterFire582_with_mask completed succesfully
# Processing parent image: RGB_AfterFire581_with_mask
# Final number of tiles for RGB_AfterFire581_with_mask: 221
#  Tiling of RGB_AfterFire581_with_mask completed succesfully
# Processing parent image: RGB_AfterFire580_with_mask
# Final number of tiles for RGB_AfterFire580_with_mask: 221
#  Tiling of RGB_AfterFire580_with_mask completed succesfully
# Processing parent image: RGB_AfterFire579_with_mask
# Final number of tiles for RGB_AfterFire579_with_mask: 221
#  Tiling of RGB_AfterFire579_with_mask completed succesfully
# Processing parent image: RGB_AfterFire578_with_mask
# Final number of tiles for RGB_AfterFire578_with_mask: 221
#  Tiling of RGB_AfterFire578_with_mask completed succesfully
# Processing parent image: RGB_AfterFire577_with_mask
# Final number of tiles for RGB_AfterFire577_with_mask: 221
#  Tiling of RGB_AfterFire577_with_mask completed succesfully
# Processing parent image: RGB_AfterFire575_with_mask
# Final number of tiles for RGB_AfterFire575_with_mask: 221
#  Tiling of RGB_AfterFire575_with_mask completed succesfully
# Processing parent image: RGB_AfterFire574_with_mask
# Final number of tiles for RGB_AfterFire574_with_mask: 221
#  Tiling of RGB_AfterFire574_with_mask completed succesfully
# Processing parent image: RGB_AfterFire571_with_mask
# Final number of tiles for RGB_AfterFire571_with_mask: 221
#  Tiling of RGB_AfterFire571_with_mask completed succesfully
# Processing parent image: RGB_AfterFire570_with_mask
# Final number of tiles for RGB_AfterFire570_with_mask: 221
#  Tiling of RGB_AfterFire570_with_mask completed succesfully
# Processing parent image: RGB_AfterFire569_with_mask
# Final number of tiles for RGB_AfterFire569_with_mask: 208
#  Tiling of RGB_AfterFire569_with_mask completed succesfully
# Processing parent image: RGB_AfterFire568_with_mask
# Final number of tiles for RGB_AfterFire568_with_mask: 208
#  Tiling of RGB_AfterFire568_with_mask completed succesfully
# Processing parent image: RGB_AfterFire567_with_mask
# Final number of tiles for RGB_AfterFire567_with_mask: 208
#  Tiling of RGB_AfterFire567_with_mask completed succesfully
# Processing parent image: RGB_AfterFire566_with_mask
# Final number of tiles for RGB_AfterFire566_with_mask: 208
#  Tiling of RGB_AfterFire566_with_mask completed succesfully
# Processing parent image: RGB_AfterFire565_with_mask
# Final number of tiles for RGB_AfterFire565_with_mask: 208
#  Tiling of RGB_AfterFire565_with_mask completed succesfully
# Processing parent image: RGB_AfterFire564_with_mask
# Final number of tiles for RGB_AfterFire564_with_mask: 208
#  Tiling of RGB_AfterFire564_with_mask completed succesfully
# Processing parent image: RGB_AfterFire562_with_mask
# Final number of tiles for RGB_AfterFire562_with_mask: 221
#  Tiling of RGB_AfterFire562_with_mask completed succesfully
# Processing parent image: RGB_AfterFire561_with_mask
# Final number of tiles for RGB_AfterFire561_with_mask: 221
#  Tiling of RGB_AfterFire561_with_mask completed succesfully
# Processing parent image: RGB_AfterFire560_with_mask
# Final number of tiles for RGB_AfterFire560_with_mask: 221
#  Tiling of RGB_AfterFire560_with_mask completed succesfully
# Processing parent image: RGB_AfterFire559_with_mask
# Final number of tiles for RGB_AfterFire559_with_mask: 221
#  Tiling of RGB_AfterFire559_with_mask completed succesfully
# Processing parent image: RGB_AfterFire558_with_mask
# Final number of tiles for RGB_AfterFire558_with_mask: 221
#  Tiling of RGB_AfterFire558_with_mask completed succesfully
# Processing parent image: RGB_AfterFire557_with_mask
# Final number of tiles for RGB_AfterFire557_with_mask: 221
#  Tiling of RGB_AfterFire557_with_mask completed succesfully
# Processing parent image: RGB_AfterFire556_with_mask
# Final number of tiles for RGB_AfterFire556_with_mask: 221
#  Tiling of RGB_AfterFire556_with_mask completed succesfully
# Processing parent image: RGB_AfterFire555_with_mask
# Final number of tiles for RGB_AfterFire555_with_mask: 208
#  Tiling of RGB_AfterFire555_with_mask completed succesfully
# Processing parent image: RGB_AfterFire554_with_mask
# Final number of tiles for RGB_AfterFire554_with_mask: 208
#  Tiling of RGB_AfterFire554_with_mask completed succesfully
# Processing parent image: RGB_AfterFire553_with_mask
# Final number of tiles for RGB_AfterFire553_with_mask: 208
#  Tiling of RGB_AfterFire553_with_mask completed succesfully
# Processing parent image: RGB_AfterFire552_with_mask
# Final number of tiles for RGB_AfterFire552_with_mask: 208
#  Tiling of RGB_AfterFire552_with_mask completed succesfully
# Processing parent image: RGB_AfterFire551_with_mask
# Final number of tiles for RGB_AfterFire551_with_mask: 208
#  Tiling of RGB_AfterFire551_with_mask completed succesfully
# Processing parent image: RGB_AfterFire548_with_mask
# Final number of tiles for RGB_AfterFire548_with_mask: 221
#  Tiling of RGB_AfterFire548_with_mask completed succesfully
# Processing parent image: RGB_AfterFire547_with_mask
# Final number of tiles for RGB_AfterFire547_with_mask: 221
#  Tiling of RGB_AfterFire547_with_mask completed succesfully
# Processing parent image: RGB_AfterFire545_with_mask
# Final number of tiles for RGB_AfterFire545_with_mask: 221
#  Tiling of RGB_AfterFire545_with_mask completed succesfully
# Processing parent image: RGB_AfterFire544_with_mask
# Final number of tiles for RGB_AfterFire544_with_mask: 208
#  Tiling of RGB_AfterFire544_with_mask completed succesfully
# Processing parent image: RGB_AfterFire541_with_mask
# Final number of tiles for RGB_AfterFire541_with_mask: 208
#  Tiling of RGB_AfterFire541_with_mask completed succesfully
# Processing parent image: RGB_AfterFire540_with_mask
# Final number of tiles for RGB_AfterFire540_with_mask: 221
#  Tiling of RGB_AfterFire540_with_mask completed succesfully
# Processing parent image: RGB_AfterFire534_with_mask
# Final number of tiles for RGB_AfterFire534_with_mask: 208
#  Tiling of RGB_AfterFire534_with_mask completed succesfully
# Processing parent image: RGB_AfterFire532_with_mask
# Final number of tiles for RGB_AfterFire532_with_mask: 221
#  Tiling of RGB_AfterFire532_with_mask completed succesfully
# Processing parent image: RGB_AfterFire531_with_mask
# Final number of tiles for RGB_AfterFire531_with_mask: 221
#  Tiling of RGB_AfterFire531_with_mask completed succesfully
# Processing parent image: RGB_AfterFire530_with_mask
# Final number of tiles for RGB_AfterFire530_with_mask: 221
#  Tiling of RGB_AfterFire530_with_mask completed succesfully
# Processing parent image: RGB_AfterFire528_with_mask
# Final number of tiles for RGB_AfterFire528_with_mask: 234
#  Tiling of RGB_AfterFire528_with_mask completed succesfully
# Processing parent image: RGB_AfterFire527_with_mask
# Final number of tiles for RGB_AfterFire527_with_mask: 221
#  Tiling of RGB_AfterFire527_with_mask completed succesfully
# Processing parent image: RGB_AfterFire526_with_mask
# Final number of tiles for RGB_AfterFire526_with_mask: 221
#  Tiling of RGB_AfterFire526_with_mask completed succesfully
# Processing parent image: RGB_AfterFire525_with_mask
# Final number of tiles for RGB_AfterFire525_with_mask: 221
#  Tiling of RGB_AfterFire525_with_mask completed succesfully
# Processing parent image: RGB_AfterFire523_with_mask
# Final number of tiles for RGB_AfterFire523_with_mask: 195
#  Tiling of RGB_AfterFire523_with_mask completed succesfully
# Processing parent image: RGB_AfterFire522_with_mask
# Final number of tiles for RGB_AfterFire522_with_mask: 208
#  Tiling of RGB_AfterFire522_with_mask completed succesfully
# Processing parent image: RGB_AfterFire521_with_mask
# Final number of tiles for RGB_AfterFire521_with_mask: 221
#  Tiling of RGB_AfterFire521_with_mask completed succesfully
# Processing parent image: RGB_AfterFire520_with_mask
# Final number of tiles for RGB_AfterFire520_with_mask: 221
#  Tiling of RGB_AfterFire520_with_mask completed succesfully
# Processing parent image: RGB_AfterFire519_with_mask
# Final number of tiles for RGB_AfterFire519_with_mask: 221
#  Tiling of RGB_AfterFire519_with_mask completed succesfully
# Processing parent image: RGB_AfterFire518_with_mask
# Final number of tiles for RGB_AfterFire518_with_mask: 221
#  Tiling of RGB_AfterFire518_with_mask completed succesfully
# Processing parent image: RGB_AfterFire517_with_mask
# Final number of tiles for RGB_AfterFire517_with_mask: 221
#  Tiling of RGB_AfterFire517_with_mask completed succesfully
# Processing parent image: RGB_AfterFire515_with_mask
# Final number of tiles for RGB_AfterFire515_with_mask: 208
#  Tiling of RGB_AfterFire515_with_mask completed succesfully
# Processing parent image: RGB_AfterFire514_with_mask
# Final number of tiles for RGB_AfterFire514_with_mask: 208
#  Tiling of RGB_AfterFire514_with_mask completed succesfully
# Processing parent image: RGB_AfterFire513_with_mask
# Final number of tiles for RGB_AfterFire513_with_mask: 208
#  Tiling of RGB_AfterFire513_with_mask completed succesfully
# Processing parent image: RGB_AfterFire510_with_mask
# Final number of tiles for RGB_AfterFire510_with_mask: 208
#  Tiling of RGB_AfterFire510_with_mask completed succesfully
# Processing parent image: RGB_AfterFire508_with_mask
# Final number of tiles for RGB_AfterFire508_with_mask: 221
#  Tiling of RGB_AfterFire508_with_mask completed succesfully
# Processing parent image: RGB_AfterFire507_with_mask
# Final number of tiles for RGB_AfterFire507_with_mask: 221
#  Tiling of RGB_AfterFire507_with_mask completed succesfully
# Processing parent image: RGB_AfterFire506_with_mask
# Final number of tiles for RGB_AfterFire506_with_mask: 221
#  Tiling of RGB_AfterFire506_with_mask completed succesfully
# Processing parent image: RGB_AfterFire505_with_mask
# Final number of tiles for RGB_AfterFire505_with_mask: 221
#  Tiling of RGB_AfterFire505_with_mask completed succesfully
# Processing parent image: RGB_AfterFire504_with_mask
# Final number of tiles for RGB_AfterFire504_with_mask: 221
#  Tiling of RGB_AfterFire504_with_mask completed succesfully
# Processing parent image: RGB_AfterFire503_with_mask
# Final number of tiles for RGB_AfterFire503_with_mask: 221
#  Tiling of RGB_AfterFire503_with_mask completed succesfully
# Processing parent image: RGB_AfterFire502_with_mask
# Final number of tiles for RGB_AfterFire502_with_mask: 208
#  Tiling of RGB_AfterFire502_with_mask completed succesfully
# Processing parent image: RGB_AfterFire501_with_mask
# Final number of tiles for RGB_AfterFire501_with_mask: 195
#  Tiling of RGB_AfterFire501_with_mask completed succesfully
# Processing parent image: RGB_AfterFire500_with_mask
# Final number of tiles for RGB_AfterFire500_with_mask: 208
#  Tiling of RGB_AfterFire500_with_mask completed succesfully
# Processing parent image: RGB_AfterFire499_with_mask
# Final number of tiles for RGB_AfterFire499_with_mask: 208
#  Tiling of RGB_AfterFire499_with_mask completed succesfully
# Processing parent image: RGB_AfterFire498_with_mask
# Final number of tiles for RGB_AfterFire498_with_mask: 208
#  Tiling of RGB_AfterFire498_with_mask completed succesfully
# Processing parent image: RGB_AfterFire496_with_mask
# Final number of tiles for RGB_AfterFire496_with_mask: 208
#  Tiling of RGB_AfterFire496_with_mask completed succesfully
# Processing parent image: RGB_AfterFire494_with_mask
# Final number of tiles for RGB_AfterFire494_with_mask: 208
#  Tiling of RGB_AfterFire494_with_mask completed succesfully
# Processing parent image: RGB_AfterFire493_with_mask
# Final number of tiles for RGB_AfterFire493_with_mask: 208
#  Tiling of RGB_AfterFire493_with_mask completed succesfully
# Processing parent image: RGB_AfterFire492_with_mask
# Final number of tiles for RGB_AfterFire492_with_mask: 208
#  Tiling of RGB_AfterFire492_with_mask completed succesfully
# Processing parent image: RGB_AfterFire490_with_mask
# Final number of tiles for RGB_AfterFire490_with_mask: 208
#  Tiling of RGB_AfterFire490_with_mask completed succesfully
# Processing parent image: RGB_AfterFire489_with_mask
# Final number of tiles for RGB_AfterFire489_with_mask: 208
#  Tiling of RGB_AfterFire489_with_mask completed succesfully
# Processing parent image: RGB_AfterFire488_with_mask
# Final number of tiles for RGB_AfterFire488_with_mask: 221
#  Tiling of RGB_AfterFire488_with_mask completed succesfully
# Processing parent image: RGB_AfterFire487_with_mask
# Final number of tiles for RGB_AfterFire487_with_mask: 221
#  Tiling of RGB_AfterFire487_with_mask completed succesfully
# Processing parent image: RGB_AfterFire486_with_mask
# Final number of tiles for RGB_AfterFire486_with_mask: 221
#  Tiling of RGB_AfterFire486_with_mask completed succesfully
# Processing parent image: RGB_AfterFire482_with_mask
# Final number of tiles for RGB_AfterFire482_with_mask: 221
#  Tiling of RGB_AfterFire482_with_mask completed succesfully
# Processing parent image: RGB_AfterFire481_with_mask
# Final number of tiles for RGB_AfterFire481_with_mask: 208
#  Tiling of RGB_AfterFire481_with_mask completed succesfully
# Processing parent image: RGB_AfterFire480_with_mask
# Final number of tiles for RGB_AfterFire480_with_mask: 208
#  Tiling of RGB_AfterFire480_with_mask completed succesfully
# Processing parent image: RGB_AfterFire477_with_mask
# Final number of tiles for RGB_AfterFire477_with_mask: 208
#  Tiling of RGB_AfterFire477_with_mask completed succesfully
# Processing parent image: RGB_AfterFire476_with_mask
# Final number of tiles for RGB_AfterFire476_with_mask: 221
#  Tiling of RGB_AfterFire476_with_mask completed succesfully
# Processing parent image: RGB_AfterFire475_with_mask
# Final number of tiles for RGB_AfterFire475_with_mask: 208
#  Tiling of RGB_AfterFire475_with_mask completed succesfully
# Processing parent image: RGB_AfterFire474_with_mask
# Final number of tiles for RGB_AfterFire474_with_mask: 221
#  Tiling of RGB_AfterFire474_with_mask completed succesfully
# Processing parent image: RGB_AfterFire473_with_mask
# Final number of tiles for RGB_AfterFire473_with_mask: 234
#  Tiling of RGB_AfterFire473_with_mask completed succesfully
# Processing parent image: RGB_AfterFire472_with_mask
# Final number of tiles for RGB_AfterFire472_with_mask: 221
#  Tiling of RGB_AfterFire472_with_mask completed succesfully
# Processing parent image: RGB_AfterFire471_with_mask
# Final number of tiles for RGB_AfterFire471_with_mask: 221
#  Tiling of RGB_AfterFire471_with_mask completed succesfully
# Processing parent image: RGB_AfterFire470_with_mask
# Final number of tiles for RGB_AfterFire470_with_mask: 208
#  Tiling of RGB_AfterFire470_with_mask completed succesfully
# Processing parent image: RGB_AfterFire468_with_mask
# Final number of tiles for RGB_AfterFire468_with_mask: 221
#  Tiling of RGB_AfterFire468_with_mask completed succesfully
# Processing parent image: RGB_AfterFire466_with_mask
# Final number of tiles for RGB_AfterFire466_with_mask: 221
#  Tiling of RGB_AfterFire466_with_mask completed succesfully
# Processing parent image: RGB_AfterFire464_with_mask
# Final number of tiles for RGB_AfterFire464_with_mask: 221
#  Tiling of RGB_AfterFire464_with_mask completed succesfully
# Processing parent image: RGB_AfterFire461_with_mask
# Final number of tiles for RGB_AfterFire461_with_mask: 208
#  Tiling of RGB_AfterFire461_with_mask completed succesfully
# Processing parent image: RGB_AfterFire460_with_mask
# Final number of tiles for RGB_AfterFire460_with_mask: 208
#  Tiling of RGB_AfterFire460_with_mask completed succesfully
# Processing parent image: RGB_AfterFire459_with_mask
# Final number of tiles for RGB_AfterFire459_with_mask: 208
#  Tiling of RGB_AfterFire459_with_mask completed succesfully
# Processing parent image: RGB_AfterFire453_with_mask
# Final number of tiles for RGB_AfterFire453_with_mask: 195
#  Tiling of RGB_AfterFire453_with_mask completed succesfully
# Processing parent image: RGB_AfterFire452_with_mask
# Final number of tiles for RGB_AfterFire452_with_mask: 208
#  Tiling of RGB_AfterFire452_with_mask completed succesfully
# Processing parent image: RGB_AfterFire451_with_mask
# Final number of tiles for RGB_AfterFire451_with_mask: 208
#  Tiling of RGB_AfterFire451_with_mask completed succesfully
# Processing parent image: RGB_AfterFire450_with_mask
# Final number of tiles for RGB_AfterFire450_with_mask: 221
#  Tiling of RGB_AfterFire450_with_mask completed succesfully
# Processing parent image: RGB_AfterFire449_with_mask
# Final number of tiles for RGB_AfterFire449_with_mask: 208
#  Tiling of RGB_AfterFire449_with_mask completed succesfully
# Processing parent image: RGB_AfterFire448_with_mask
# Final number of tiles for RGB_AfterFire448_with_mask: 208
#  Tiling of RGB_AfterFire448_with_mask completed succesfully
# Processing parent image: RGB_AfterFire446_with_mask
# Final number of tiles for RGB_AfterFire446_with_mask: 208
#  Tiling of RGB_AfterFire446_with_mask completed succesfully
# Processing parent image: RGB_AfterFire444_with_mask
# Final number of tiles for RGB_AfterFire444_with_mask: 208
#  Tiling of RGB_AfterFire444_with_mask completed succesfully
# Processing parent image: RGB_AfterFire441_with_mask
# Final number of tiles for RGB_AfterFire441_with_mask: 221
#  Tiling of RGB_AfterFire441_with_mask completed succesfully
# Processing parent image: RGB_AfterFire440_with_mask
# Final number of tiles for RGB_AfterFire440_with_mask: 221
#  Tiling of RGB_AfterFire440_with_mask completed succesfully
# Processing parent image: RGB_AfterFire439_with_mask
# Final number of tiles for RGB_AfterFire439_with_mask: 208
#  Tiling of RGB_AfterFire439_with_mask completed succesfully
# Processing parent image: RGB_AfterFire438_with_mask
# Final number of tiles for RGB_AfterFire438_with_mask: 221
#  Tiling of RGB_AfterFire438_with_mask completed succesfully
# Processing parent image: RGB_AfterFire436_with_mask
# Final number of tiles for RGB_AfterFire436_with_mask: 221
#  Tiling of RGB_AfterFire436_with_mask completed succesfully
# Processing parent image: RGB_AfterFire432_with_mask
# Final number of tiles for RGB_AfterFire432_with_mask: 208
#  Tiling of RGB_AfterFire432_with_mask completed succesfully
# Processing parent image: RGB_AfterFire430_with_mask
# Final number of tiles for RGB_AfterFire430_with_mask: 208
#  Tiling of RGB_AfterFire430_with_mask completed succesfully
# Processing parent image: RGB_AfterFire428_with_mask
# Final number of tiles for RGB_AfterFire428_with_mask: 208
#  Tiling of RGB_AfterFire428_with_mask completed succesfully
# Processing parent image: RGB_AfterFire426_with_mask
# Final number of tiles for RGB_AfterFire426_with_mask: 221
#  Tiling of RGB_AfterFire426_with_mask completed succesfully
# Processing parent image: RGB_AfterFire422_with_mask
# Final number of tiles for RGB_AfterFire422_with_mask: 221
#  Tiling of RGB_AfterFire422_with_mask completed succesfully
# Processing parent image: RGB_AfterFire417_with_mask
# Final number of tiles for RGB_AfterFire417_with_mask: 221
#  Tiling of RGB_AfterFire417_with_mask completed succesfully
# Processing parent image: RGB_AfterFire416_with_mask
# Final number of tiles for RGB_AfterFire416_with_mask: 221
#  Tiling of RGB_AfterFire416_with_mask completed succesfully
# Processing parent image: RGB_AfterFire415_with_mask
# Final number of tiles for RGB_AfterFire415_with_mask: 221
#  Tiling of RGB_AfterFire415_with_mask completed succesfully
# Processing parent image: RGB_AfterFire413_with_mask
# Final number of tiles for RGB_AfterFire413_with_mask: 208
#  Tiling of RGB_AfterFire413_with_mask completed succesfully
# Processing parent image: RGB_AfterFire411_with_mask
# Final number of tiles for RGB_AfterFire411_with_mask: 221
#  Tiling of RGB_AfterFire411_with_mask completed succesfully
# Processing parent image: RGB_AfterFire410_with_mask
# Final number of tiles for RGB_AfterFire410_with_mask: 221
#  Tiling of RGB_AfterFire410_with_mask completed succesfully
# Processing parent image: RGB_AfterFire409_with_mask
# Final number of tiles for RGB_AfterFire409_with_mask: 221
#  Tiling of RGB_AfterFire409_with_mask completed succesfully
# Processing parent image: RGB_AfterFire408_with_mask
# Final number of tiles for RGB_AfterFire408_with_mask: 221
#  Tiling of RGB_AfterFire408_with_mask completed succesfully
# Processing parent image: RGB_AfterFire407_with_mask
# Final number of tiles for RGB_AfterFire407_with_mask: 221
#  Tiling of RGB_AfterFire407_with_mask completed succesfully
# Processing parent image: RGB_AfterFire406_with_mask
# Final number of tiles for RGB_AfterFire406_with_mask: 208
#  Tiling of RGB_AfterFire406_with_mask completed succesfully
# Processing parent image: RGB_AfterFire405_with_mask
# Final number of tiles for RGB_AfterFire405_with_mask: 208
#  Tiling of RGB_AfterFire405_with_mask completed succesfully
# Processing parent image: RGB_AfterFire403_with_mask
# Final number of tiles for RGB_AfterFire403_with_mask: 221
#  Tiling of RGB_AfterFire403_with_mask completed succesfully
# Processing parent image: RGB_AfterFire402_with_mask
# Final number of tiles for RGB_AfterFire402_with_mask: 221
#  Tiling of RGB_AfterFire402_with_mask completed succesfully
# Processing parent image: RGB_AfterFire401_with_mask
# Final number of tiles for RGB_AfterFire401_with_mask: 208
#  Tiling of RGB_AfterFire401_with_mask completed succesfully
# Processing parent image: RGB_AfterFire400_with_mask
# Final number of tiles for RGB_AfterFire400_with_mask: 208
#  Tiling of RGB_AfterFire400_with_mask completed succesfully
# Processing parent image: RGB_AfterFire399_with_mask
# Final number of tiles for RGB_AfterFire399_with_mask: 221
#  Tiling of RGB_AfterFire399_with_mask completed succesfully
# Processing parent image: RGB_AfterFire395_with_mask
# Final number of tiles for RGB_AfterFire395_with_mask: 221
#  Tiling of RGB_AfterFire395_with_mask completed succesfully
# Processing parent image: RGB_AfterFire394_with_mask
# Final number of tiles for RGB_AfterFire394_with_mask: 208
#  Tiling of RGB_AfterFire394_with_mask completed succesfully
# Processing parent image: RGB_AfterFire392_with_mask
# Final number of tiles for RGB_AfterFire392_with_mask: 234
#  Tiling of RGB_AfterFire392_with_mask completed succesfully
# Processing parent image: RGB_AfterFire390_with_mask
# Final number of tiles for RGB_AfterFire390_with_mask: 221
#  Tiling of RGB_AfterFire390_with_mask completed succesfully
# Processing parent image: RGB_AfterFire389_with_mask
# Final number of tiles for RGB_AfterFire389_with_mask: 221
#  Tiling of RGB_AfterFire389_with_mask completed succesfully
# Processing parent image: RGB_AfterFire388_with_mask
# Final number of tiles for RGB_AfterFire388_with_mask: 208
#  Tiling of RGB_AfterFire388_with_mask completed succesfully
# Processing parent image: RGB_AfterFire387_with_mask
# Final number of tiles for RGB_AfterFire387_with_mask: 208
#  Tiling of RGB_AfterFire387_with_mask completed succesfully
# Processing parent image: RGB_AfterFire385_with_mask
# Final number of tiles for RGB_AfterFire385_with_mask: 221
#  Tiling of RGB_AfterFire385_with_mask completed succesfully
# Processing parent image: RGB_AfterFire381_with_mask
# Final number of tiles for RGB_AfterFire381_with_mask: 221
#  Tiling of RGB_AfterFire381_with_mask completed succesfully
# Processing parent image: RGB_AfterFire380_with_mask
# Final number of tiles for RGB_AfterFire380_with_mask: 221
#  Tiling of RGB_AfterFire380_with_mask completed succesfully
# Processing parent image: RGB_AfterFire377_with_mask
# Final number of tiles for RGB_AfterFire377_with_mask: 234
#  Tiling of RGB_AfterFire377_with_mask completed succesfully
# Processing parent image: RGB_AfterFire373_with_mask
# Final number of tiles for RGB_AfterFire373_with_mask: 221
#  Tiling of RGB_AfterFire373_with_mask completed succesfully
# Processing parent image: RGB_AfterFire372_with_mask
# Final number of tiles for RGB_AfterFire372_with_mask: 221
#  Tiling of RGB_AfterFire372_with_mask completed succesfully
# Processing parent image: RGB_AfterFire367_with_mask
# Final number of tiles for RGB_AfterFire367_with_mask: 234
#  Tiling of RGB_AfterFire367_with_mask completed succesfully
# Processing parent image: RGB_AfterFire366_with_mask
# Final number of tiles for RGB_AfterFire366_with_mask: 221
#  Tiling of RGB_AfterFire366_with_mask completed succesfully
# Processing parent image: RGB_AfterFire365_with_mask
# Final number of tiles for RGB_AfterFire365_with_mask: 234
#  Tiling of RGB_AfterFire365_with_mask completed succesfully
# Processing parent image: RGB_AfterFire364_with_mask
# Final number of tiles for RGB_AfterFire364_with_mask: 208
#  Tiling of RGB_AfterFire364_with_mask completed succesfully
# Processing parent image: RGB_AfterFire363_with_mask
# Final number of tiles for RGB_AfterFire363_with_mask: 208
#  Tiling of RGB_AfterFire363_with_mask completed succesfully
# Processing parent image: RGB_AfterFire362_with_mask
# Final number of tiles for RGB_AfterFire362_with_mask: 208
#  Tiling of RGB_AfterFire362_with_mask completed succesfully
# Processing parent image: RGB_AfterFire361_with_mask
# Final number of tiles for RGB_AfterFire361_with_mask: 208
#  Tiling of RGB_AfterFire361_with_mask completed succesfully
# Processing parent image: RGB_AfterFire360_with_mask
# Final number of tiles for RGB_AfterFire360_with_mask: 208
#  Tiling of RGB_AfterFire360_with_mask completed succesfully
# Processing parent image: RGB_AfterFire359_with_mask
# Final number of tiles for RGB_AfterFire359_with_mask: 208
#  Tiling of RGB_AfterFire359_with_mask completed succesfully
# Processing parent image: RGB_AfterFire358_with_mask
# Final number of tiles for RGB_AfterFire358_with_mask: 208
#  Tiling of RGB_AfterFire358_with_mask completed succesfully
# Processing parent image: RGB_AfterFire357_with_mask
# Final number of tiles for RGB_AfterFire357_with_mask: 208
#  Tiling of RGB_AfterFire357_with_mask completed succesfully
# Processing parent image: RGB_AfterFire356_with_mask
# Final number of tiles for RGB_AfterFire356_with_mask: 208
#  Tiling of RGB_AfterFire356_with_mask completed succesfully
# Processing parent image: RGB_AfterFire355_with_mask
# Final number of tiles for RGB_AfterFire355_with_mask: 208
#  Tiling of RGB_AfterFire355_with_mask completed succesfully
# Processing parent image: RGB_AfterFire354_with_mask
# Final number of tiles for RGB_AfterFire354_with_mask: 208
#  Tiling of RGB_AfterFire354_with_mask completed succesfully
# Processing parent image: RGB_AfterFire353_with_mask
# Final number of tiles for RGB_AfterFire353_with_mask: 208
#  Tiling of RGB_AfterFire353_with_mask completed succesfully
# Processing parent image: RGB_AfterFire352_with_mask
# Final number of tiles for RGB_AfterFire352_with_mask: 208
#  Tiling of RGB_AfterFire352_with_mask completed succesfully
# Processing parent image: RGB_AfterFire351_with_mask
# Final number of tiles for RGB_AfterFire351_with_mask: 195
#  Tiling of RGB_AfterFire351_with_mask completed succesfully
# Processing parent image: RGB_AfterFire350_with_mask
# Final number of tiles for RGB_AfterFire350_with_mask: 208
#  Tiling of RGB_AfterFire350_with_mask completed succesfully
# Processing parent image: RGB_AfterFire349_with_mask
# Final number of tiles for RGB_AfterFire349_with_mask: 208
#  Tiling of RGB_AfterFire349_with_mask completed succesfully
# Processing parent image: RGB_AfterFire348_with_mask
# Final number of tiles for RGB_AfterFire348_with_mask: 221
#  Tiling of RGB_AfterFire348_with_mask completed succesfully
# Processing parent image: RGB_AfterFire347_with_mask
# Final number of tiles for RGB_AfterFire347_with_mask: 221
#  Tiling of RGB_AfterFire347_with_mask completed succesfully
# Processing parent image: RGB_AfterFire345_with_mask
# Final number of tiles for RGB_AfterFire345_with_mask: 221
#  Tiling of RGB_AfterFire345_with_mask completed succesfully
# Processing parent image: RGB_AfterFire342_with_mask
# Final number of tiles for RGB_AfterFire342_with_mask: 221
#  Tiling of RGB_AfterFire342_with_mask completed succesfully
# Processing parent image: RGB_AfterFire335_with_mask
# Final number of tiles for RGB_AfterFire335_with_mask: 221
#  Tiling of RGB_AfterFire335_with_mask completed succesfully
# Processing parent image: RGB_AfterFire333_with_mask
# Final number of tiles for RGB_AfterFire333_with_mask: 208
#  Tiling of RGB_AfterFire333_with_mask completed succesfully
# Processing parent image: RGB_AfterFire331_with_mask
# Final number of tiles for RGB_AfterFire331_with_mask: 208
#  Tiling of RGB_AfterFire331_with_mask completed succesfully
# Processing parent image: RGB_AfterFire330_with_mask
# Final number of tiles for RGB_AfterFire330_with_mask: 208
#  Tiling of RGB_AfterFire330_with_mask completed succesfully
# Processing parent image: RGB_AfterFire329_with_mask
# Final number of tiles for RGB_AfterFire329_with_mask: 221
#  Tiling of RGB_AfterFire329_with_mask completed succesfully
# Processing parent image: RGB_AfterFire328_with_mask
# Final number of tiles for RGB_AfterFire328_with_mask: 221
#  Tiling of RGB_AfterFire328_with_mask completed succesfully
# Processing parent image: RGB_AfterFire324_with_mask
# Final number of tiles for RGB_AfterFire324_with_mask: 221
#  Tiling of RGB_AfterFire324_with_mask completed succesfully
# Processing parent image: RGB_AfterFire322_with_mask
# Final number of tiles for RGB_AfterFire322_with_mask: 221
#  Tiling of RGB_AfterFire322_with_mask completed succesfully
# Processing parent image: RGB_AfterFire321_with_mask
# Final number of tiles for RGB_AfterFire321_with_mask: 221
#  Tiling of RGB_AfterFire321_with_mask completed succesfully
# Processing parent image: RGB_AfterFire319_with_mask
# Final number of tiles for RGB_AfterFire319_with_mask: 221
#  Tiling of RGB_AfterFire319_with_mask completed succesfully
# Processing parent image: RGB_AfterFire316_with_mask
# Final number of tiles for RGB_AfterFire316_with_mask: 208
#  Tiling of RGB_AfterFire316_with_mask completed succesfully
# Processing parent image: RGB_AfterFire310_with_mask
# Final number of tiles for RGB_AfterFire310_with_mask: 208
#  Tiling of RGB_AfterFire310_with_mask completed succesfully
# Processing parent image: RGB_AfterFire309_with_mask
# Final number of tiles for RGB_AfterFire309_with_mask: 208
#  Tiling of RGB_AfterFire309_with_mask completed succesfully
# Processing parent image: RGB_AfterFire308_with_mask
# Final number of tiles for RGB_AfterFire308_with_mask: 208
#  Tiling of RGB_AfterFire308_with_mask completed succesfully
# Processing parent image: RGB_AfterFire307_with_mask
# Final number of tiles for RGB_AfterFire307_with_mask: 208
#  Tiling of RGB_AfterFire307_with_mask completed succesfully
# Processing parent image: RGB_AfterFire303_with_mask
# Final number of tiles for RGB_AfterFire303_with_mask: 221
#  Tiling of RGB_AfterFire303_with_mask completed succesfully
# Processing parent image: RGB_AfterFire301_with_mask
# Final number of tiles for RGB_AfterFire301_with_mask: 221
#  Tiling of RGB_AfterFire301_with_mask completed succesfully
# Processing parent image: RGB_AfterFire299_with_mask
# Final number of tiles for RGB_AfterFire299_with_mask: 221
#  Tiling of RGB_AfterFire299_with_mask completed succesfully
# Processing parent image: RGB_AfterFire295_with_mask
# Final number of tiles for RGB_AfterFire295_with_mask: 221
#  Tiling of RGB_AfterFire295_with_mask completed succesfully
# Processing parent image: RGB_AfterFire293_with_mask
# Final number of tiles for RGB_AfterFire293_with_mask: 221
#  Tiling of RGB_AfterFire293_with_mask completed succesfully
# Processing parent image: RGB_AfterFire292_with_mask
# Final number of tiles for RGB_AfterFire292_with_mask: 208
#  Tiling of RGB_AfterFire292_with_mask completed succesfully
# Processing parent image: RGB_AfterFire285_with_mask
# Final number of tiles for RGB_AfterFire285_with_mask: 208
#  Tiling of RGB_AfterFire285_with_mask completed succesfully
# Processing parent image: RGB_AfterFire284_with_mask
# Final number of tiles for RGB_AfterFire284_with_mask: 208
#  Tiling of RGB_AfterFire284_with_mask completed succesfully
# Processing parent image: RGB_AfterFire283_with_mask
# Final number of tiles for RGB_AfterFire283_with_mask: 208
#  Tiling of RGB_AfterFire283_with_mask completed succesfully
# Processing parent image: RGB_AfterFire282_with_mask
# Final number of tiles for RGB_AfterFire282_with_mask: 221
#  Tiling of RGB_AfterFire282_with_mask completed succesfully
# Processing parent image: RGB_AfterFire281_with_mask
# Final number of tiles for RGB_AfterFire281_with_mask: 208
#  Tiling of RGB_AfterFire281_with_mask completed succesfully
# Processing parent image: RGB_AfterFire280_with_mask
# Final number of tiles for RGB_AfterFire280_with_mask: 195
#  Tiling of RGB_AfterFire280_with_mask completed succesfully
# Processing parent image: RGB_AfterFire278_with_mask
# ...
# Final number of tiles for RGB_AfterFire259_with_mask: 208
#  Tiling of RGB_AfterFire259_with_mask completed succesfully
# Processing parent image: RGB_AfterFire255_with_mask
# Final number of tiles for RGB_AfterFire255_with_mask: 208
#  Tiling of RGB_AfterFire255_with_mask completed succesfully
# Processing parent image: RGB_AfterFire254_with_mask
# Final number of tiles for RGB_AfterFire254_with_mask: 208
#  Tiling of RGB_AfterFire254_with_mask completed succesfully
# Processing parent image: RGB_AfterFire252_with_mask
# Final number of tiles for RGB_AfterFire252_with_mask: 221
#  Tiling of RGB_AfterFire252_with_mask completed succesfully
# Processing parent image: RGB_AfterFire243_with_mask
# Final number of tiles for RGB_AfterFire243_with_mask: 208
#  Tiling of RGB_AfterFire243_with_mask completed succesfully
# Processing parent image: RGB_AfterFire238_with_mask
# Final number of tiles for RGB_AfterFire238_with_mask: 208
#  Tiling of RGB_AfterFire238_with_mask completed succesfully
# Processing parent image: RGB_AfterFire237_with_mask
# Final number of tiles for RGB_AfterFire237_with_mask: 221
#  Tiling of RGB_AfterFire237_with_mask completed succesfully
# Processing parent image: RGB_AfterFire233_with_mask
# Final number of tiles for RGB_AfterFire233_with_mask: 208
#  Tiling of RGB_AfterFire233_with_mask completed succesfully
# Processing parent image: RGB_AfterFire232_with_mask
# Final number of tiles for RGB_AfterFire232_with_mask: 221
#  Tiling of RGB_AfterFire232_with_mask completed succesfully
# Processing parent image: RGB_AfterFire229_with_mask
# Final number of tiles for RGB_AfterFire229_with_mask: 221
#  Tiling of RGB_AfterFire229_with_mask completed succesfully
# Processing parent image: RGB_AfterFire226_with_mask
# Final number of tiles for RGB_AfterFire226_with_mask: 208
#  Tiling of RGB_AfterFire226_with_mask completed succesfully
# Processing parent image: RGB_AfterFire225_with_mask
# Final number of tiles for RGB_AfterFire225_with_mask: 208
#  Tiling of RGB_AfterFire225_with_mask completed succesfully
# Processing parent image: RGB_AfterFire224_with_mask
# Final number of tiles for RGB_AfterFire224_with_mask: 208
#  Tiling of RGB_AfterFire224_with_mask completed succesfully
# Processing parent image: RGB_AfterFire220_with_mask
# Final number of tiles for RGB_AfterFire220_with_mask: 208
#  Tiling of RGB_AfterFire220_with_mask completed succesfully
# Processing parent image: RGB_AfterFire216_with_mask
# Final number of tiles for RGB_AfterFire216_with_mask: 221
#  Tiling of RGB_AfterFire216_with_mask completed succesfully
# Processing parent image: RGB_AfterFire214_with_mask
# Final number of tiles for RGB_AfterFire214_with_mask: 221
#  Tiling of RGB_AfterFire214_with_mask completed succesfully
# Processing parent image: RGB_AfterFire213_with_mask
# Final number of tiles for RGB_AfterFire213_with_mask: 208
#  Tiling of RGB_AfterFire213_with_mask completed succesfully
# Processing parent image: RGB_AfterFire210_with_mask
# Final number of tiles for RGB_AfterFire210_with_mask: 221
#  Tiling of RGB_AfterFire210_with_mask completed succesfully
# Processing parent image: RGB_AfterFire209_with_mask
# Final number of tiles for RGB_AfterFire209_with_mask: 208
#  Tiling of RGB_AfterFire209_with_mask completed succesfully
# Processing parent image: RGB_AfterFire207_with_mask
# Final number of tiles for RGB_AfterFire207_with_mask: 208
#  Tiling of RGB_AfterFire207_with_mask completed succesfully
# Processing parent image: RGB_AfterFire206_with_mask
# Final number of tiles for RGB_AfterFire206_with_mask: 208
#  Tiling of RGB_AfterFire206_with_mask completed succesfully
# Processing parent image: RGB_AfterFire205_with_mask
# Final number of tiles for RGB_AfterFire205_with_mask: 221
#  Tiling of RGB_AfterFire205_with_mask completed succesfully
# Processing parent image: RGB_AfterFire202_with_mask
# Final number of tiles for RGB_AfterFire202_with_mask: 221
#  Tiling of RGB_AfterFire202_with_mask completed succesfully
# Processing parent image: RGB_AfterFire200_with_mask
# Final number of tiles for RGB_AfterFire200_with_mask: 208
#  Tiling of RGB_AfterFire200_with_mask completed succesfully
# Processing parent image: RGB_AfterFire198_with_mask
# Final number of tiles for RGB_AfterFire198_with_mask: 208
#  Tiling of RGB_AfterFire198_with_mask completed succesfully
# Processing parent image: RGB_AfterFire196_with_mask
# Final number of tiles for RGB_AfterFire196_with_mask: 221
#  Tiling of RGB_AfterFire196_with_mask completed succesfully
# Processing parent image: RGB_AfterFire191_with_mask
# Final number of tiles for RGB_AfterFire191_with_mask: 208
#  Tiling of RGB_AfterFire191_with_mask completed succesfully
# Processing parent image: RGB_AfterFire188_with_mask
# Final number of tiles for RGB_AfterFire188_with_mask: 195
#  Tiling of RGB_AfterFire188_with_mask completed succesfully
# Processing parent image: RGB_AfterFire187_with_mask
# Final number of tiles for RGB_AfterFire187_with_mask: 221
#  Tiling of RGB_AfterFire187_with_mask completed succesfully
# Processing parent image: RGB_AfterFire186_with_mask
# Final number of tiles for RGB_AfterFire186_with_mask: 221
#  Tiling of RGB_AfterFire186_with_mask completed succesfully
# Processing parent image: RGB_AfterFire185_with_mask
# Final number of tiles for RGB_AfterFire185_with_mask: 221
#  Tiling of RGB_AfterFire185_with_mask completed succesfully
# Processing parent image: RGB_AfterFire183_with_mask
# Final number of tiles for RGB_AfterFire183_with_mask: 221
#  Tiling of RGB_AfterFire183_with_mask completed succesfully
# Processing parent image: RGB_AfterFire181_with_mask
# Final number of tiles for RGB_AfterFire181_with_mask: 221
#  Tiling of RGB_AfterFire181_with_mask completed succesfully
# Processing parent image: RGB_AfterFire179_with_mask
# Final number of tiles for RGB_AfterFire179_with_mask: 208
#  Tiling of RGB_AfterFire179_with_mask completed succesfully
# Processing parent image: RGB_AfterFire178_with_mask
# Final number of tiles for RGB_AfterFire178_with_mask: 208
#  Tiling of RGB_AfterFire178_with_mask completed succesfully
# Processing parent image: RGB_AfterFire164_with_mask
# Final number of tiles for RGB_AfterFire164_with_mask: 221
#  Tiling of RGB_AfterFire164_with_mask completed succesfully
# Processing parent image: RGB_AfterFire161_with_mask
# Final number of tiles for RGB_AfterFire161_with_mask: 208
#  Tiling of RGB_AfterFire161_with_mask completed succesfully
# Processing parent image: RGB_AfterFire160_with_mask
# Final number of tiles for RGB_AfterFire160_with_mask: 221
#  Tiling of RGB_AfterFire160_with_mask completed succesfully
# Processing parent image: RGB_AfterFire152_with_mask
# Final number of tiles for RGB_AfterFire152_with_mask: 208
#  Tiling of RGB_AfterFire152_with_mask completed succesfully
# Processing parent image: RGB_AfterFire151_with_mask
# Final number of tiles for RGB_AfterFire151_with_mask: 221
#  Tiling of RGB_AfterFire151_with_mask completed succesfully
# Processing parent image: RGB_AfterFire145_with_mask
# Final number of tiles for RGB_AfterFire145_with_mask: 221
#  Tiling of RGB_AfterFire145_with_mask completed succesfully
# Processing parent image: RGB_AfterFire144_with_mask
# Final number of tiles for RGB_AfterFire144_with_mask: 208
#  Tiling of RGB_AfterFire144_with_mask completed succesfully
# Processing parent image: RGB_AfterFire143_with_mask
# Final number of tiles for RGB_AfterFire143_with_mask: 208
#  Tiling of RGB_AfterFire143_with_mask completed succesfully
# Processing parent image: RGB_AfterFire141_with_mask
# Final number of tiles for RGB_AfterFire141_with_mask: 208
#  Tiling of RGB_AfterFire141_with_mask completed succesfully
# Processing parent image: RGB_AfterFire135_with_mask
# Final number of tiles for RGB_AfterFire135_with_mask: 208
#  Tiling of RGB_AfterFire135_with_mask completed succesfully
# Processing parent image: RGB_AfterFire133_with_mask
# Final number of tiles for RGB_AfterFire133_with_mask: 208
#  Tiling of RGB_AfterFire133_with_mask completed succesfully
# Processing parent image: RGB_AfterFire130_with_mask
# Final number of tiles for RGB_AfterFire130_with_mask: 221
#  Tiling of RGB_AfterFire130_with_mask completed succesfully
# Processing parent image: RGB_AfterFire126_with_mask
# Final number of tiles for RGB_AfterFire126_with_mask: 221
#  Tiling of RGB_AfterFire126_with_mask completed succesfully
# Processing parent image: RGB_AfterFire125_with_mask
# Final number of tiles for RGB_AfterFire125_with_mask: 208
#  Tiling of RGB_AfterFire125_with_mask completed succesfully
# Processing parent image: RGB_AfterFire123_with_mask
# Final number of tiles for RGB_AfterFire123_with_mask: 221
#  Tiling of RGB_AfterFire123_with_mask completed succesfully
# Processing parent image: RGB_AfterFire122_with_mask
# Final number of tiles for RGB_AfterFire122_with_mask: 221
#  Tiling of RGB_AfterFire122_with_mask completed succesfully
# Processing parent image: RGB_AfterFire118_with_mask
# Final number of tiles for RGB_AfterFire118_with_mask: 221
#  Tiling of RGB_AfterFire118_with_mask completed succesfully
# Processing parent image: RGB_AfterFire117_with_mask
# Final number of tiles for RGB_AfterFire117_with_mask: 221
#  Tiling of RGB_AfterFire117_with_mask completed succesfully
# Processing parent image: RGB_AfterFire116_with_mask
# Final number of tiles for RGB_AfterFire116_with_mask: 208
#  Tiling of RGB_AfterFire116_with_mask completed succesfully
# Processing parent image: RGB_AfterFire115_with_mask
# Final number of tiles for RGB_AfterFire115_with_mask: 208
#  Tiling of RGB_AfterFire115_with_mask completed succesfully
# Processing parent image: RGB_AfterFire112_with_mask
# Final number of tiles for RGB_AfterFire112_with_mask: 208
#  Tiling of RGB_AfterFire112_with_mask completed succesfully
# Processing parent image: RGB_AfterFire48_with_mask
# Final number of tiles for RGB_AfterFire48_with_mask: 221
#  Tiling of RGB_AfterFire48_with_mask completed succesfully
# Processing parent image: RGB_AfterFire47_with_mask
# Final number of tiles for RGB_AfterFire47_with_mask: 221
#  Tiling of RGB_AfterFire47_with_mask completed succesfully
# Processing parent image: RGB_AfterFire46_with_mask
# Final number of tiles for RGB_AfterFire46_with_mask: 208
#  Tiling of RGB_AfterFire46_with_mask completed succesfully
# Processing parent image: RGB_AfterFire44_with_mask
# Final number of tiles for RGB_AfterFire44_with_mask: 208
#  Tiling of RGB_AfterFire44_with_mask completed succesfully
# Processing parent image: RGB_AfterFire43_with_mask
# Final number of tiles for RGB_AfterFire43_with_mask: 208
#  Tiling of RGB_AfterFire43_with_mask completed succesfully
# Processing parent image: RGB_AfterFire42_with_mask
# Final number of tiles for RGB_AfterFire42_with_mask: 221
#  Tiling of RGB_AfterFire42_with_mask completed succesfully
# Processing parent image: RGB_AfterFire39_with_mask
# Final number of tiles for RGB_AfterFire39_with_mask: 221
#  Tiling of RGB_AfterFire39_with_mask completed succesfully
# Processing parent image: RGB_AfterFire37_with_mask
# Final number of tiles for RGB_AfterFire37_with_mask: 221
#  Tiling of RGB_AfterFire37_with_mask completed succesfully
# Processing parent image: RGB_AfterFire36_with_mask
# Final number of tiles for RGB_AfterFire36_with_mask: 221
#  Tiling of RGB_AfterFire36_with_mask completed succesfully
# Processing parent image: RGB_AfterFire35_with_mask
# Final number of tiles for RGB_AfterFire35_with_mask: 221
#  Tiling of RGB_AfterFire35_with_mask completed succesfully
# Processing parent image: RGB_AfterFire33_with_mask
# Final number of tiles for RGB_AfterFire33_with_mask: 208
#  Tiling of RGB_AfterFire33_with_mask completed succesfully
# Processing parent image: RGB_AfterFire32_with_mask
# Final number of tiles for RGB_AfterFire32_with_mask: 221
#  Tiling of RGB_AfterFire32_with_mask completed succesfully
# Processing parent image: RGB_AfterFire30_with_mask
# Final number of tiles for RGB_AfterFire30_with_mask: 208
#  Tiling of RGB_AfterFire30_with_mask completed succesfully
# Processing parent image: RGB_AfterFire29_with_mask
# Final number of tiles for RGB_AfterFire29_with_mask: 208
#  Tiling of RGB_AfterFire29_with_mask completed succesfully
# Processing parent image: RGB_AfterFire28_with_mask
# Final number of tiles for RGB_AfterFire28_with_mask: 208
#  Tiling of RGB_AfterFire28_with_mask completed succesfully
# Processing parent image: RGB_AfterFire27_with_mask
# Final number of tiles for RGB_AfterFire27_with_mask: 208
#  Tiling of RGB_AfterFire27_with_mask completed succesfully
# Processing parent image: RGB_AfterFire26_with_mask
# Final number of tiles for RGB_AfterFire26_with_mask: 208
#  Tiling of RGB_AfterFire26_with_mask completed succesfully
# Processing parent image: RGB_AfterFire25_with_mask
# Final number of tiles for RGB_AfterFire25_with_mask: 208
#  Tiling of RGB_AfterFire25_with_mask completed succesfully
# Processing parent image: RGB_AfterFire23_with_mask
# Final number of tiles for RGB_AfterFire23_with_mask: 221
#  Tiling of RGB_AfterFire23_with_mask completed succesfully
# Processing parent image: RGB_AfterFire22_with_mask
# Final number of tiles for RGB_AfterFire22_with_mask: 221
#  Tiling of RGB_AfterFire22_with_mask completed succesfully
# Processing parent image: RGB_AfterFire21_with_mask
# Final number of tiles for RGB_AfterFire21_with_mask: 221
#  Tiling of RGB_AfterFire21_with_mask completed succesfully
# Processing parent image: RGB_AfterFire20_with_mask
# Final number of tiles for RGB_AfterFire20_with_mask: 221
#  Tiling of RGB_AfterFire20_with_mask completed succesfully
# Processing parent image: RGB_AfterFire19_with_mask
# Final number of tiles for RGB_AfterFire19_with_mask: 221
#  Tiling of RGB_AfterFire19_with_mask completed succesfully
# Processing parent image: RGB_AfterFire18_with_mask
# Final number of tiles for RGB_AfterFire18_with_mask: 221
#  Tiling of RGB_AfterFire18_with_mask completed succesfully
# Processing parent image: RGB_AfterFire17_with_mask
# Final number of tiles for RGB_AfterFire17_with_mask: 221
#  Tiling of RGB_AfterFire17_with_mask completed succesfully
# Processing parent image: RGB_AfterFire16_with_mask
# Final number of tiles for RGB_AfterFire16_with_mask: 221
#  Tiling of RGB_AfterFire16_with_mask completed succesfully
# Processing parent image: RGB_AfterFire15_with_mask
# Final number of tiles for RGB_AfterFire15_with_mask: 208
#  Tiling of RGB_AfterFire15_with_mask completed succesfully
# Processing parent image: RGB_AfterFire14_with_mask
# Final number of tiles for RGB_AfterFire14_with_mask: 221
#  Tiling of RGB_AfterFire14_with_mask completed succesfully
# Processing parent image: RGB_AfterFire13_with_mask
# Final number of tiles for RGB_AfterFire13_with_mask: 221
#  Tiling of RGB_AfterFire13_with_mask completed succesfully
# Processing parent image: RGB_AfterFire11_with_mask
# Final number of tiles for RGB_AfterFire11_with_mask: 208
#  Tiling of RGB_AfterFire11_with_mask completed succesfully
# Processing parent image: RGB_AfterFire10_with_mask
# Final number of tiles for RGB_AfterFire10_with_mask: 221
#  Tiling of RGB_AfterFire10_with_mask completed succesfully
# Processing parent image: RGB_AfterFire9_with_mask
# Final number of tiles for RGB_AfterFire9_with_mask: 208
#  Tiling of RGB_AfterFire9_with_mask completed succesfully
# Processing parent image: RGB_AfterFire8_with_mask
# Final number of tiles for RGB_AfterFire8_with_mask: 221
#  Tiling of RGB_AfterFire8_with_mask completed succesfully
# Processing parent image: RGB_AfterFire7_with_mask
# Final number of tiles for RGB_AfterFire7_with_mask: 208
#  Tiling of RGB_AfterFire7_with_mask completed succesfully
# Processing parent image: RGB_AfterFire6_with_mask
# Final number of tiles for RGB_AfterFire6_with_mask: 208
#  Tiling of RGB_AfterFire6_with_mask completed succesfully
# Processing parent image: RGB_AfterFire5_with_mask
# Final number of tiles for RGB_AfterFire5_with_mask: 208
#  Tiling of RGB_AfterFire5_with_mask completed succesfully
# Processing parent image: RGB_AfterFire4_with_mask
# Final number of tiles for RGB_AfterFire4_with_mask: 221
#  Tiling of RGB_AfterFire4_with_mask completed succesfully
# Processing parent image: RGB_AfterFire2_with_mask
# Final number of tiles for RGB_AfterFire2_with_mask: 221
#  Tiling of RGB_AfterFire2_with_mask completed succesfully
# Processing parent image: RGB_AfterFire1_with_mask
# Final number of tiles for RGB_AfterFire1_with_mask: 221
#  Tiling of RGB_AfterFire1_with_mask completed succesfully
