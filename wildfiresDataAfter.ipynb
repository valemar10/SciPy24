# %% [markdown]
# # Notebook to download Sentinel-2 Satellite GeoTIFF images of forested areas in California after documented wildfires using Google Earth Engine (GEE)
# ## The data points and polygons were gathered from the folowing [Esri Living Atlas Layer ](https://pns.maps.arcgis.com/home/item.html?id=6fd0d8d6f47d414da7bcb1dcd0539999)
# - The layer was preprocessed in ArcGIS Pro:
#     - The layer was filtered to get dates from 2016 because we plan on using sentinel.
#     - The layer was clipped using the Forest Service of the Original Proclaimed National Forest Land layer.
#     - The Feature to point tool was used.
#     - The Get XY point tool was applied.
#     - The final layer attribute table was saved as an excel file "fireForest.xls"
#
# #### Import packages and libraries

# %%
#Import the necessary libraries and packages
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import pyproj
import warnings
warnings.filterwarnings('ignore')
from shapely.geometry import Point, Polygon
from geopy.distance import great_circle
import ee
import geemap
import numpy as np
import geetools
import time

# %% [markdown]
# ## Define the processed files to be used and the after dates

# %%
excel_file_path = 'ExcelFiles/DataFireFinal.xlsx'  
df = pd.read_excel(excel_file_path)
# Drop the specified columns
columns_to_drop = ['15_Days_Before_Incident', '1_Day_Before_Incident', 'Incident_Date', 'Containment_Date']
df = df.drop(columns=columns_to_drop)

# Drop rows where '1_Day_After_Containment' or '15_Days_After_Containment' is empty

df = df.dropna(subset=['1_Day_After_Containment', '15_Days_After_Containment'])

# Convert the date columns to datetime if they are not already in datetime format
df['1_Day_After_Containment'] = pd.to_datetime(df['1_Day_After_Containment'])
df['15_Days_After_Containment'] = pd.to_datetime(df['15_Days_After_Containment'])

# Drop rows where either '1_Day_After_Containment' or '15_Days_After_Containment' is '2020-01-01'
df = df.loc[~((df['1_Day_After_Containment'] == '2020-01-01') | (df['15_Days_After_Containment'] == '2020-01-01'))]

# Revert the datetime columns back to their original format (as strings)
df['1_Day_After_Containment'] = df['1_Day_After_Containment'].dt.strftime('%Y-%m-%d')
df['15_Days_After_Containment'] = df['15_Days_After_Containment'].dt.strftime('%Y-%m-%d')

dataAfter = df.values

# %% [markdown]
# ## Download the After Wildfire RGB and NDVI images using GEE
#
# ### Install and authenticate GEE

# %%
#Authenticate 
ee.Authenticate()

#initialize ee
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8dxs7lGQrm_b1rHu6l42sZf8mJvR6Kjyb6_kSdERcSo&tc=-_Dm7ngSQgkg3omoEXjpWi8wEwfo2TVialMzVv79xdI&cc=1l_RGXL2sSqDM3fRQOe5auhEKtfq3R2kkVg80-NOzHE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8dxs7lGQrm_b1rHu6l42sZf8mJvR6Kjyb6_kSdERcSo&tc=-_Dm7ngSQgkg3omoEXjpWi8wEwfo2TVialMzVv79xdI&cc=1l_RGXL2sSqDM3fRQOe5auhEKtfq3R2kkVg80-NOzHE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AfJohXkwhH13QN6J3ZObpOLliw59cHD6jwBlgwtP9qgB524rAeLsJTIY19I
# Successfully saved authorization token.

# %% [markdown]
# ### Export the RGB and NDVI GeoTIFFs (B2, B3, B4, and B8) Images for After the fire event using GEE.

# %%
num = []
for i in range(331, 1000):
    num.append(i)

# Define the bands you want to download
bands_rgb = ['B4', 'B3', 'B2']  # Red, Green, Blue
bands_ndvi = ['B8', 'B4']  # NIR, Red

# Function to calculate NDVI
def calculate_ndvi(image):
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi)

for i in num:
    # Set the center point
    point = ee.Geometry.Point(round(dataAfter[i][1], 2), round(dataAfter[i][2], 2))

    # Call an image for the selected point
    tile = ee.ImageCollection('COPERNICUS/S2') \
        .filterBounds(point) \
        .filterDate(dataAfter[i][3], dataAfter[i][4]) \
        .sort('CLOUDY_PIXEL_PERCENTAGE') \
        .first()
    # Check the properties of the image
    image_properties = tile.getInfo()
    cloudy_percentage = image_properties.get('properties', {}).get('CLOUDY_PIXEL_PERCENTAGE', 0)
    if cloudy_percentage <= 10:
        # Define the ROI
        roi = ee.Geometry.Polygon([[
            [dataAfter[i][5], dataAfter[i][6]],
            [dataAfter[i][7], dataAfter[i][8]],
            [dataAfter[i][9], dataAfter[i][10]],
            [dataAfter[i][11], dataAfter[i][12]],
            [dataAfter[i][13], dataAfter[i][14]]]])

        # Add NDVI to the selected bands
        tile_with_ndvi = calculate_ndvi(tile)

        # Select RGB and NDVI bands
        rgb_tile = tile.select(bands_rgb)
        ndvi_tile = tile_with_ndvi.select(['NDVI'])

        # Export RGB image to Google Drive
        rgb_task = ee.batch.Export.image.toDrive(**{
            'image': rgb_tile,
            'description': 'RGB_AfterFire' + str(dataAfter[i][0]),
            'folder': 'GEE_FireImagesRGB_after',
            'scale': 10,  # Adjust the scale as needed
            'region': roi.getInfo()['coordinates'],
            'crs': 'EPSG:4326',
            'fileFormat': 'GeoTIFF',
        })
        rgb_task.start()

        # Export NDVI image to Google Drive
        ndvi_task = ee.batch.Export.image.toDrive(**{
            'image': ndvi_tile,
            'description': 'NDVI_AfterFire' + str(dataAfter[i][0]),
            'folder': 'GEE_FireImagesNDVI_after',
            'scale': 10,  # Adjust the scale as needed
            'region': roi.getInfo()['coordinates'],
            'crs': 'EPSG:4326',
            'fileFormat': 'GeoTIFF',
        })
        ndvi_task.start()

        # Wait for the tasks to complete
        while not (rgb_task.status()['state'] in ['COMPLETED', 'FAILED', 'CANCELLED'] and
                   ndvi_task.status()['state'] in ['COMPLETED', 'FAILED', 'CANCELLED']):
            print('RGB Task is', rgb_task.status()['state'])
            print('NDVI Task is', ndvi_task.status()['state'])
            time.sleep(90)  # Wait for 90 seconds before checking again

        # Check the final task statuses
        rgb_task_status = rgb_task.status()
        ndvi_task_status = ndvi_task.status()
        print("RGB Task Status:", rgb_task_status)
        print("NDVI Task Status:", ndvi_task_status)
        print("RGB Task Error Message:", rgb_task_status.get("error_message", "No error message"))
        print("NDVI Task Error Message:", ndvi_task_status.get("error_message", "No error message"))
    else:
        print(f"Skipping image {i} due to cloudy percentage ({cloudy_percentage}%) > 10%")
# Out:
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire464', 'creation_timestamp_ms': 1700803626453, 'update_timestamp_ms': 1700804150179, 'start_timestamp_ms': 1700803888768, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.219398498535156, 'id': 'YXTRRLLKHTLN77OQEEN5WRA4', 'name': 'projects/earthengine-legacy/operations/YXTRRLLKHTLN77OQEEN5WRA4'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire464', 'creation_timestamp_ms': 1700803627249, 'update_timestamp_ms': 1700804156279, 'start_timestamp_ms': 1700803896421, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 16.64292335510254, 'id': 'XGWBOSXTULBCPTFOEZRSO73D', 'name': 'projects/earthengine-legacy/operations/XGWBOSXTULBCPTFOEZRSO73D'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 332 due to cloudy percentage (67.1115%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire466', 'creation_timestamp_ms': 1700804174832, 'update_timestamp_ms': 1700804677564, 'start_timestamp_ms': 1700804401659, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.6180419921875, 'id': 'OJRAA3IXTFW6KVOYHDALPCV2', 'name': 'projects/earthengine-legacy/operations/OJRAA3IXTFW6KVOYHDALPCV2'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire466', 'creation_timestamp_ms': 1700804175702, 'update_timestamp_ms': 1700804693975, 'start_timestamp_ms': 1700804411607, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.75897216796875, 'id': 'LBQZGO7DQIFACQ2JLGZTJ4WF', 'name': 'projects/earthengine-legacy/operations/LBQZGO7DQIFACQ2JLGZTJ4WF'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire467', 'creation_timestamp_ms': 1700804723289, 'update_timestamp_ms': 1700805213016, 'start_timestamp_ms': 1700804948837, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.847139358520508, 'id': 'PJS7GT376KUTOSCQNNHMEBBJ', 'name': 'projects/earthengine-legacy/operations/PJS7GT376KUTOSCQNNHMEBBJ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire467', 'creation_timestamp_ms': 1700804723916, 'update_timestamp_ms': 1700805232560, 'start_timestamp_ms': 1700804966744, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 30.947856903076172, 'id': '7JGLKC5WX4QFLIJTH2OFGVV2', 'name': 'projects/earthengine-legacy/operations/7JGLKC5WX4QFLIJTH2OFGVV2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire468', 'creation_timestamp_ms': 1700805274877, 'update_timestamp_ms': 1700805768889, 'start_timestamp_ms': 1700805501985, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 31.529844284057617, 'id': 'NNK5ZCIKDC63YEINLUW5HFLI', 'name': 'projects/earthengine-legacy/operations/NNK5ZCIKDC63YEINLUW5HFLI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire468', 'creation_timestamp_ms': 1700805275517, 'update_timestamp_ms': 1700805772114, 'start_timestamp_ms': 1700805508855, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.933551788330078, 'id': 'PDH4VPKOY32UWDB3RM4LPMML', 'name': 'projects/earthengine-legacy/operations/PDH4VPKOY32UWDB3RM4LPMML'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire470', 'creation_timestamp_ms': 1700805827495, 'update_timestamp_ms': 1700806305889, 'start_timestamp_ms': 1700806043995, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.56032943725586, 'id': '4JNV5CYZWVXYEWBK6PCKCI4V', 'name': 'projects/earthengine-legacy/operations/4JNV5CYZWVXYEWBK6PCKCI4V'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire470', 'creation_timestamp_ms': 1700805828122, 'update_timestamp_ms': 1700806303557, 'start_timestamp_ms': 1700806043999, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.729766845703125, 'id': 'OJSQBFQP4KVX6IVR2M5BVNHN', 'name': 'projects/earthengine-legacy/operations/OJSQBFQP4KVX6IVR2M5BVNHN'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire471', 'creation_timestamp_ms': 1700806375773, 'update_timestamp_ms': 1700806840114, 'start_timestamp_ms': 1700806575415, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.915430068969727, 'id': 'S4ZSNKZX4FF36W5S4YTFBVVE', 'name': 'projects/earthengine-legacy/operations/S4ZSNKZX4FF36W5S4YTFBVVE'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire471', 'creation_timestamp_ms': 1700806376413, 'update_timestamp_ms': 1700806936551, 'start_timestamp_ms': 1700806590244, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.06139373779297, 'id': 'YEE4OKXM4TINQUTF3E75UOL3', 'name': 'projects/earthengine-legacy/operations/YEE4OKXM4TINQUTF3E75UOL3'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire472', 'creation_timestamp_ms': 1700807014681, 'update_timestamp_ms': 1700807485128, 'start_timestamp_ms': 1700807221199, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.465333938598633, 'id': 'QTQDD3R376T6MQ66EA45SAA2', 'name': 'projects/earthengine-legacy/operations/QTQDD3R376T6MQ66EA45SAA2'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire472', 'creation_timestamp_ms': 1700807015411, 'update_timestamp_ms': 1700807506542, 'start_timestamp_ms': 1700807228941, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.48351287841797, 'id': 'FUZIHEWUZZM5YLIPE7MOXYSE', 'name': 'projects/earthengine-legacy/operations/FUZIHEWUZZM5YLIPE7MOXYSE'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire473', 'creation_timestamp_ms': 1700807561851, 'update_timestamp_ms': 1700808636432, 'start_timestamp_ms': 1700807757566, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 54.3309440612793, 'id': '4I7ZSRMENLLMJHAEZC6QQVGT', 'name': 'projects/earthengine-legacy/operations/4I7ZSRMENLLMJHAEZC6QQVGT'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire473', 'creation_timestamp_ms': 1700807562482, 'update_timestamp_ms': 1700808065162, 'start_timestamp_ms': 1700807775198, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.066246032714844, 'id': 'MFSFW3ADFJET62YEH7V62L7G', 'name': 'projects/earthengine-legacy/operations/MFSFW3ADFJET62YEH7V62L7G'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire474', 'creation_timestamp_ms': 1700808655803, 'update_timestamp_ms': 1700808937464, 'start_timestamp_ms': 1700808661915, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 37.13084411621094, 'id': 'AUV3YU35364YPZUI6SWPTQDI', 'name': 'projects/earthengine-legacy/operations/AUV3YU35364YPZUI6SWPTQDI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire474', 'creation_timestamp_ms': 1700808656457, 'update_timestamp_ms': 1700808940845, 'start_timestamp_ms': 1700808679557, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.306224822998047, 'id': 'P4DSMKF4JTMY4DNQK35JQBKF', 'name': 'projects/earthengine-legacy/operations/P4DSMKF4JTMY4DNQK35JQBKF'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire475', 'creation_timestamp_ms': 1700809021419, 'update_timestamp_ms': 1700809489048, 'start_timestamp_ms': 1700809231231, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.59410285949707, 'id': '4C3QGYTHIBXZBTOB5SNWVDIO', 'name': 'projects/earthengine-legacy/operations/4C3QGYTHIBXZBTOB5SNWVDIO'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire475', 'creation_timestamp_ms': 1700809022005, 'update_timestamp_ms': 1700809503914, 'start_timestamp_ms': 1700809244375, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.610883712768555, 'id': 'GKK4VQ63VGQEAYWVDNIVWJJY', 'name': 'projects/earthengine-legacy/operations/GKK4VQ63VGQEAYWVDNIVWJJY'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire476', 'creation_timestamp_ms': 1700809568665, 'update_timestamp_ms': 1700810044225, 'start_timestamp_ms': 1700809767874, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.577369689941406, 'id': 'R7CAOQCJIXZ746IAREBSOZMF', 'name': 'projects/earthengine-legacy/operations/R7CAOQCJIXZ746IAREBSOZMF'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire476', 'creation_timestamp_ms': 1700809569304, 'update_timestamp_ms': 1700810056685, 'start_timestamp_ms': 1700809788282, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 30.618236541748047, 'id': 'I3W5FVGOB3UQUUN54LFW4GF5', 'name': 'projects/earthengine-legacy/operations/I3W5FVGOB3UQUUN54LFW4GF5'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire477', 'creation_timestamp_ms': 1700810116116, 'update_timestamp_ms': 1700810587271, 'start_timestamp_ms': 1700810326487, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.981626510620117, 'id': 'J4IVSQANPXVIRQEXHTO6NEXV', 'name': 'projects/earthengine-legacy/operations/J4IVSQANPXVIRQEXHTO6NEXV'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire477', 'creation_timestamp_ms': 1700810116787, 'update_timestamp_ms': 1700810668589, 'start_timestamp_ms': 1700810411320, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.535564422607422, 'id': 'MVDW73AH7YIHVAGUCOKI2U7Y', 'name': 'projects/earthengine-legacy/operations/MVDW73AH7YIHVAGUCOKI2U7Y'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 344 due to cloudy percentage (71.8632%) > 10%
# Skipping image 345 due to cloudy percentage (25.5011%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire480', 'creation_timestamp_ms': 1700810755412, 'update_timestamp_ms': 1700811122227, 'start_timestamp_ms': 1700810867181, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.131141662597656, 'id': 'EKWQ77AOOVBDC4LBLEZIUVET', 'name': 'projects/earthengine-legacy/operations/EKWQ77AOOVBDC4LBLEZIUVET'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire480', 'creation_timestamp_ms': 1700810756005, 'update_timestamp_ms': 1700811212861, 'start_timestamp_ms': 1700810951779, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.856473922729492, 'id': 'CFL4MY7XYK4W5LGG5PJFADXN', 'name': 'projects/earthengine-legacy/operations/CFL4MY7XYK4W5LGG5PJFADXN'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire481', 'creation_timestamp_ms': 1700811307761, 'update_timestamp_ms': 1700811604824, 'start_timestamp_ms': 1700811339487, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.85329246520996, 'id': 'DWM4HDEFQHND633PZ5CKCBV2', 'name': 'projects/earthengine-legacy/operations/DWM4HDEFQHND633PZ5CKCBV2'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire481', 'creation_timestamp_ms': 1700811308497, 'update_timestamp_ms': 1700811815941, 'start_timestamp_ms': 1700811537377, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.64842414855957, 'id': '3PXAC5KQTIZQSZZK54CJNNJ6', 'name': 'projects/earthengine-legacy/operations/3PXAC5KQTIZQSZZK54CJNNJ6'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire482', 'creation_timestamp_ms': 1700811857071, 'update_timestamp_ms': 1700812199989, 'start_timestamp_ms': 1700811922885, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.5855712890625, 'id': '7T3W4RREAH7RSRYFYUZCB2JA', 'name': 'projects/earthengine-legacy/operations/7T3W4RREAH7RSRYFYUZCB2JA'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire482', 'creation_timestamp_ms': 1700811857665, 'update_timestamp_ms': 1700812373422, 'start_timestamp_ms': 1700812104004, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.57184600830078, 'id': '2SSVJFAWQRFRKVUFFSTCXV64', 'name': 'projects/earthengine-legacy/operations/2SSVJFAWQRFRKVUFFSTCXV64'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire485', 'creation_timestamp_ms': 1700812404760, 'update_timestamp_ms': 1700812741799, 'start_timestamp_ms': 1700812478258, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.729082107543945, 'id': 'LOQHDW3NVOGJHL4CABKF36GQ', 'name': 'projects/earthengine-legacy/operations/LOQHDW3NVOGJHL4CABKF36GQ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire485', 'creation_timestamp_ms': 1700812405382, 'update_timestamp_ms': 1700812900943, 'start_timestamp_ms': 1700812640789, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.004169464111328, 'id': 'PZKHRI5B3RO7SWK4HJUC6DQ2', 'name': 'projects/earthengine-legacy/operations/PZKHRI5B3RO7SWK4HJUC6DQ2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire486', 'creation_timestamp_ms': 1700812953396, 'update_timestamp_ms': 1700813329911, 'start_timestamp_ms': 1700813038255, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 44.20893859863281, 'id': 'CJTEBDPIEZCWIIO4ZUXA6DEH', 'name': 'projects/earthengine-legacy/operations/CJTEBDPIEZCWIIO4ZUXA6DEH'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire486', 'creation_timestamp_ms': 1700812954162, 'update_timestamp_ms': 1700813452010, 'start_timestamp_ms': 1700813173390, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.758663177490234, 'id': '5MJR4YK6FNTO7KT27XX34E6K', 'name': 'projects/earthengine-legacy/operations/5MJR4YK6FNTO7KT27XX34E6K'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire487', 'creation_timestamp_ms': 1700813506750, 'update_timestamp_ms': 1700813943612, 'start_timestamp_ms': 1700813664309, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 35.116661071777344, 'id': '5NHDDA23G2VKNEBLKTPBUZFT', 'name': 'projects/earthengine-legacy/operations/5NHDDA23G2VKNEBLKTPBUZFT'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire487', 'creation_timestamp_ms': 1700813507435, 'update_timestamp_ms': 1700813974596, 'start_timestamp_ms': 1700813709653, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.3594970703125, 'id': 'PJUHOQACTGTH3BZ4SBCIWLA4', 'name': 'projects/earthengine-legacy/operations/PJUHOQACTGTH3BZ4SBCIWLA4'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire488', 'creation_timestamp_ms': 1700814055010, 'update_timestamp_ms': 1700814536837, 'start_timestamp_ms': 1700814210872, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 45.81086349487305, 'id': 'EAGY2HR6ASOQ7M7UCILKUYNN', 'name': 'projects/earthengine-legacy/operations/EAGY2HR6ASOQ7M7UCILKUYNN'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire488', 'creation_timestamp_ms': 1700814055977, 'update_timestamp_ms': 1700814519046, 'start_timestamp_ms': 1700814257303, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.909591674804688, 'id': 'J23D3O4W7YHWDYB7MV6P63FH', 'name': 'projects/earthengine-legacy/operations/J23D3O4W7YHWDYB7MV6P63FH'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire489', 'creation_timestamp_ms': 1700814603076, 'update_timestamp_ms': 1700815123711, 'start_timestamp_ms': 1700814787173, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 47.568199157714844, 'id': '77DIW2KGAP766FHP2CEIKZIE', 'name': 'projects/earthengine-legacy/operations/77DIW2KGAP766FHP2CEIKZIE'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire489', 'creation_timestamp_ms': 1700814603732, 'update_timestamp_ms': 1700815071723, 'start_timestamp_ms': 1700814813276, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.7698917388916, 'id': 'PX5HRE37YKKK3SJ73D7VFPP3', 'name': 'projects/earthengine-legacy/operations/PX5HRE37YKKK3SJ73D7VFPP3'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire490', 'creation_timestamp_ms': 1700815151455, 'update_timestamp_ms': 1700815623495, 'start_timestamp_ms': 1700815362135, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.45438003540039, 'id': 'U6UOZJLM7BUME36RI4Z4I73L', 'name': 'projects/earthengine-legacy/operations/U6UOZJLM7BUME36RI4Z4I73L'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire490', 'creation_timestamp_ms': 1700815152182, 'update_timestamp_ms': 1700815718045, 'start_timestamp_ms': 1700815436261, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 36.78928756713867, 'id': 'M5CPPCBRUXFHVRU2BR2B3FZ2', 'name': 'projects/earthengine-legacy/operations/M5CPPCBRUXFHVRU2BR2B3FZ2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 355 due to cloudy percentage (22.1163%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire492', 'creation_timestamp_ms': 1700815793615, 'update_timestamp_ms': 1700816177792, 'start_timestamp_ms': 1700815918115, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.86678695678711, 'id': 'PISE7JOKEZQLEJ5IMAU4VYWO', 'name': 'projects/earthengine-legacy/operations/PISE7JOKEZQLEJ5IMAU4VYWO'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire492', 'creation_timestamp_ms': 1700815794225, 'update_timestamp_ms': 1700816259861, 'start_timestamp_ms': 1700816004909, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.77914047241211, 'id': 'FQQLOBPLWEPLLEXSR6JW3ZYB', 'name': 'projects/earthengine-legacy/operations/FQQLOBPLWEPLLEXSR6JW3ZYB'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire493', 'creation_timestamp_ms': 1700816340702, 'update_timestamp_ms': 1700816736695, 'start_timestamp_ms': 1700816473174, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.172983169555664, 'id': 'XHD33HAENCZVVKDPGJKKJ5RU', 'name': 'projects/earthengine-legacy/operations/XHD33HAENCZVVKDPGJKKJ5RU'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire493', 'creation_timestamp_ms': 1700816341381, 'update_timestamp_ms': 1700816792488, 'start_timestamp_ms': 1700816533866, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.14240264892578, 'id': 'WHYYAR7YUVNA57Y263K6BXX7', 'name': 'projects/earthengine-legacy/operations/WHYYAR7YUVNA57Y263K6BXX7'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire494', 'creation_timestamp_ms': 1700816798706, 'update_timestamp_ms': 1700817275859, 'start_timestamp_ms': 1700817008769, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.621646881103516, 'id': 'WJUE6DMHL6PHDBS6JPF3UJWC', 'name': 'projects/earthengine-legacy/operations/WJUE6DMHL6PHDBS6JPF3UJWC'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire494', 'creation_timestamp_ms': 1700816799373, 'update_timestamp_ms': 1700817333352, 'start_timestamp_ms': 1700817078796, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.438867568969727, 'id': 'MKAJIMF6PK7V4UAMPRAJ5EX4', 'name': 'projects/earthengine-legacy/operations/MKAJIMF6PK7V4UAMPRAJ5EX4'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire495', 'creation_timestamp_ms': 1700817345998, 'update_timestamp_ms': 1700817831921, 'start_timestamp_ms': 1700817569044, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.493873596191406, 'id': 'VRTU5M6IGXBFMYKN7OTMG4SN', 'name': 'projects/earthengine-legacy/operations/VRTU5M6IGXBFMYKN7OTMG4SN'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire495', 'creation_timestamp_ms': 1700817346627, 'update_timestamp_ms': 1700817905904, 'start_timestamp_ms': 1700817638598, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.80819320678711, 'id': '6XZXM7GGQOZMMDCEKN4VQANA', 'name': 'projects/earthengine-legacy/operations/6XZXM7GGQOZMMDCEKN4VQANA'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire496', 'creation_timestamp_ms': 1700817988915, 'update_timestamp_ms': 1700818417085, 'start_timestamp_ms': 1700818118121, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 43.29640579223633, 'id': 'NLHMRNVFAN25NOOY7IDN6247', 'name': 'projects/earthengine-legacy/operations/NLHMRNVFAN25NOOY7IDN6247'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire496', 'creation_timestamp_ms': 1700817989476, 'update_timestamp_ms': 1700818434452, 'start_timestamp_ms': 1700818173713, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.383535385131836, 'id': 'W5575R34HH4B4O6MHZHIFKDY', 'name': 'projects/earthengine-legacy/operations/W5575R34HH4B4O6MHZHIFKDY'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 361 due to cloudy percentage (23.9906%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire498', 'creation_timestamp_ms': 1700818446567, 'update_timestamp_ms': 1700818949192, 'start_timestamp_ms': 1700818687189, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.30365753173828, 'id': 'P64OK7KB3GANWQR4VVTJ7FQ6', 'name': 'projects/earthengine-legacy/operations/P64OK7KB3GANWQR4VVTJ7FQ6'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire498', 'creation_timestamp_ms': 1700818447177, 'update_timestamp_ms': 1700818954613, 'start_timestamp_ms': 1700818699387, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 14.302371978759766, 'id': 'ZQYDJUJZIX5WYLVABQQ5N7CU', 'name': 'projects/earthengine-legacy/operations/ZQYDJUJZIX5WYLVABQQ5N7CU'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire499', 'creation_timestamp_ms': 1700818995791, 'update_timestamp_ms': 1700819463441, 'start_timestamp_ms': 1700819202866, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.7362060546875, 'id': 'FLLR4TVB2HKRSSOGUDYKGSL3', 'name': 'projects/earthengine-legacy/operations/FLLR4TVB2HKRSSOGUDYKGSL3'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire499', 'creation_timestamp_ms': 1700818996713, 'update_timestamp_ms': 1700819483070, 'start_timestamp_ms': 1700819214956, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.108627319335938, 'id': 'G5JCXJKIP5ZWOO7HB3GAGHZ2', 'name': 'projects/earthengine-legacy/operations/G5JCXJKIP5ZWOO7HB3GAGHZ2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire500', 'creation_timestamp_ms': 1700819543533, 'update_timestamp_ms': 1700819999317, 'start_timestamp_ms': 1700819740480, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.637409210205078, 'id': 'CCJ6ONSRDL4CIRTI4TGLJJBY', 'name': 'projects/earthengine-legacy/operations/CCJ6ONSRDL4CIRTI4TGLJJBY'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire500', 'creation_timestamp_ms': 1700819544087, 'update_timestamp_ms': 1700820073018, 'start_timestamp_ms': 1700819810691, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.05831527709961, 'id': 'CIMMTBAOVVGSLZQ5CQYZDEGA', 'name': 'projects/earthengine-legacy/operations/CIMMTBAOVVGSLZQ5CQYZDEGA'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire501', 'creation_timestamp_ms': 1700820091987, 'update_timestamp_ms': 1700820516654, 'start_timestamp_ms': 1700820282059, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.211013793945312, 'id': 'ZWUX3H37SMSNRFNCSEAWQKLS', 'name': 'projects/earthengine-legacy/operations/ZWUX3H37SMSNRFNCSEAWQKLS'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire501', 'creation_timestamp_ms': 1700820092616, 'update_timestamp_ms': 1700820578487, 'start_timestamp_ms': 1700820338788, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 13.799782752990723, 'id': '3PVIRYZGNYD4QXIAPXZBSQXO', 'name': 'projects/earthengine-legacy/operations/3PVIRYZGNYD4QXIAPXZBSQXO'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire502', 'creation_timestamp_ms': 1700820639192, 'update_timestamp_ms': 1700821049100, 'start_timestamp_ms': 1700820789123, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.46506690979004, 'id': 'LN2BB6QVGQOSP6FCQNVQ5CUQ', 'name': 'projects/earthengine-legacy/operations/LN2BB6QVGQOSP6FCQNVQ5CUQ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire502', 'creation_timestamp_ms': 1700820640127, 'update_timestamp_ms': 1700821103883, 'start_timestamp_ms': 1700820846519, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.243383407592773, 'id': 'CQSBM2JR542UPAMACCPKB2FA', 'name': 'projects/earthengine-legacy/operations/CQSBM2JR542UPAMACCPKB2FA'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire503', 'creation_timestamp_ms': 1700821188674, 'update_timestamp_ms': 1700821655018, 'start_timestamp_ms': 1700821350274, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.09589767456055, 'id': '6C7DVUC3EZRS5EAMSM53D726', 'name': 'projects/earthengine-legacy/operations/6C7DVUC3EZRS5EAMSM53D726'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire503', 'creation_timestamp_ms': 1700821189263, 'update_timestamp_ms': 1700821667575, 'start_timestamp_ms': 1700821404506, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.813716888427734, 'id': 'TL3MKVTJDVDC6XGNBL2OZH4P', 'name': 'projects/earthengine-legacy/operations/TL3MKVTJDVDC6XGNBL2OZH4P'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire504', 'creation_timestamp_ms': 1700821736002, 'update_timestamp_ms': 1700822200073, 'start_timestamp_ms': 1700821942150, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.18480110168457, 'id': 'I4LLUV2EKAY3NQEC3PD4MWCI', 'name': 'projects/earthengine-legacy/operations/I4LLUV2EKAY3NQEC3PD4MWCI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire504', 'creation_timestamp_ms': 1700821736753, 'update_timestamp_ms': 1700822278119, 'start_timestamp_ms': 1700821979541, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.264406204223633, 'id': 'B6RNWF7AMEYPT5GUOLFVYAUU', 'name': 'projects/earthengine-legacy/operations/B6RNWF7AMEYPT5GUOLFVYAUU'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire505', 'creation_timestamp_ms': 1700822283690, 'update_timestamp_ms': 1700822771305, 'start_timestamp_ms': 1700822488792, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.664762496948242, 'id': 'IX5PTANEJHF2JOOR6ZCCAJI2', 'name': 'projects/earthengine-legacy/operations/IX5PTANEJHF2JOOR6ZCCAJI2'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire505', 'creation_timestamp_ms': 1700822284270, 'update_timestamp_ms': 1700822821224, 'start_timestamp_ms': 1700822558898, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.66684913635254, 'id': 'BBQABBO4SI4J2SLIW5WN65HJ', 'name': 'projects/earthengine-legacy/operations/BBQABBO4SI4J2SLIW5WN65HJ'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire506', 'creation_timestamp_ms': 1700822831013, 'update_timestamp_ms': 1700823323022, 'start_timestamp_ms': 1700823046302, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.155609130859375, 'id': 'TVU5XNHLL6BEAQYHEQGVPNYE', 'name': 'projects/earthengine-legacy/operations/TVU5XNHLL6BEAQYHEQGVPNYE'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire506', 'creation_timestamp_ms': 1700822831786, 'update_timestamp_ms': 1700823352463, 'start_timestamp_ms': 1700823093226, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.56143569946289, 'id': '4743M5GIESTCTAT7S7ZA6NUN', 'name': 'projects/earthengine-legacy/operations/4743M5GIESTCTAT7S7ZA6NUN'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire507', 'creation_timestamp_ms': 1700823381293, 'update_timestamp_ms': 1700823892453, 'start_timestamp_ms': 1700823598854, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 35.624996185302734, 'id': '33RICZL4I7J55YXYUYQAI6XA', 'name': 'projects/earthengine-legacy/operations/33RICZL4I7J55YXYUYQAI6XA'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire507', 'creation_timestamp_ms': 1700823381966, 'update_timestamp_ms': 1700823904713, 'start_timestamp_ms': 1700823622097, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.84868049621582, 'id': 'JWIKW5C774DPSE624AKLTVRL', 'name': 'projects/earthengine-legacy/operations/JWIKW5C774DPSE624AKLTVRL'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire508', 'creation_timestamp_ms': 1700823929221, 'update_timestamp_ms': 1700824452942, 'start_timestamp_ms': 1700824170177, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 35.43861770629883, 'id': 'HCPFHABPE46ZDC74FEWVS5KB', 'name': 'projects/earthengine-legacy/operations/HCPFHABPE46ZDC74FEWVS5KB'}
# ...
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire699', 'creation_timestamp_ms': 1700887250808, 'update_timestamp_ms': 1700887544763, 'start_timestamp_ms': 1700887263243, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.309959411621094, 'id': 'XALFM6GHXFBDGM7DCXVGEH3A', 'name': 'projects/earthengine-legacy/operations/XALFM6GHXFBDGM7DCXVGEH3A'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire699', 'creation_timestamp_ms': 1700887251530, 'update_timestamp_ms': 1700887726628, 'start_timestamp_ms': 1700887461794, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.322526931762695, 'id': 'AENQ5UABUZONLXSUZFNQAACD', 'name': 'projects/earthengine-legacy/operations/AENQ5UABUZONLXSUZFNQAACD'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 558 due to cloudy percentage (22.1163%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire701', 'creation_timestamp_ms': 1700887804437, 'update_timestamp_ms': 1700888091181, 'start_timestamp_ms': 1700887832999, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.280406951904297, 'id': '5UZWM7XFH3AG4IP3CNHMZ3AV', 'name': 'projects/earthengine-legacy/operations/5UZWM7XFH3AG4IP3CNHMZ3AV'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire701', 'creation_timestamp_ms': 1700887805561, 'update_timestamp_ms': 1700888113027, 'start_timestamp_ms': 1700887847300, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.564655303955078, 'id': 'LLF5GYV6NMJYBEJQUT5RC4MB', 'name': 'projects/earthengine-legacy/operations/LLF5GYV6NMJYBEJQUT5RC4MB'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire702', 'creation_timestamp_ms': 1700888175101, 'update_timestamp_ms': 1700888505539, 'start_timestamp_ms': 1700888251979, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 38.30760955810547, 'id': '4QF4PQYD2D2HLGBLWZESTMMI', 'name': 'projects/earthengine-legacy/operations/4QF4PQYD2D2HLGBLWZESTMMI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire702', 'creation_timestamp_ms': 1700888175967, 'update_timestamp_ms': 1700888662083, 'start_timestamp_ms': 1700888406340, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.222277641296387, 'id': 'YUCSEVWIQWGIONTFKOUT6R5Q', 'name': 'projects/earthengine-legacy/operations/YUCSEVWIQWGIONTFKOUT6R5Q'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire703', 'creation_timestamp_ms': 1700888728543, 'update_timestamp_ms': 1700889059564, 'start_timestamp_ms': 1700888781939, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.8714599609375, 'id': '373PPYYZV7DOFKLHUNJLVWV3', 'name': 'projects/earthengine-legacy/operations/373PPYYZV7DOFKLHUNJLVWV3'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire703', 'creation_timestamp_ms': 1700888729383, 'update_timestamp_ms': 1700889204778, 'start_timestamp_ms': 1700888925144, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.226285934448242, 'id': 'OATC5ZUF5W5EIIJPIKMWOTUY', 'name': 'projects/earthengine-legacy/operations/OATC5ZUF5W5EIIJPIKMWOTUY'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire704', 'creation_timestamp_ms': 1700889277619, 'update_timestamp_ms': 1700889590180, 'start_timestamp_ms': 1700889333280, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 29.342971801757812, 'id': '5XEQ6E7BOD2WFCQLMYH4G3CF', 'name': 'projects/earthengine-legacy/operations/5XEQ6E7BOD2WFCQLMYH4G3CF'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire704', 'creation_timestamp_ms': 1700889278262, 'update_timestamp_ms': 1700889767682, 'start_timestamp_ms': 1700889511445, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.455035209655762, 'id': 'SNLYKGWRHCDB6ZTSD2RFHNFI', 'name': 'projects/earthengine-legacy/operations/SNLYKGWRHCDB6ZTSD2RFHNFI'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire705', 'creation_timestamp_ms': 1700889825996, 'update_timestamp_ms': 1700890132273, 'start_timestamp_ms': 1700889860760, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.52874183654785, 'id': 'XIZ7MFSBMJNXNZ6FZONSUCLC', 'name': 'projects/earthengine-legacy/operations/XIZ7MFSBMJNXNZ6FZONSUCLC'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire705', 'creation_timestamp_ms': 1700889826723, 'update_timestamp_ms': 1700890284798, 'start_timestamp_ms': 1700890021347, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.20890235900879, 'id': 'YWKCQYNHLSWS33UJQ4EIMDLU', 'name': 'projects/earthengine-legacy/operations/YWKCQYNHLSWS33UJQ4EIMDLU'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire706', 'creation_timestamp_ms': 1700890375523, 'update_timestamp_ms': 1700890665400, 'start_timestamp_ms': 1700890401555, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.589284896850586, 'id': 'Y6HB5QLDZRBZQAGBB4VWARCJ', 'name': 'projects/earthengine-legacy/operations/Y6HB5QLDZRBZQAGBB4VWARCJ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire706', 'creation_timestamp_ms': 1700890376066, 'update_timestamp_ms': 1700890821282, 'start_timestamp_ms': 1700890559837, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.53887367248535, 'id': 'UDJN6RVJR2HLPVNLNTPV3WR4', 'name': 'projects/earthengine-legacy/operations/UDJN6RVJR2HLPVNLNTPV3WR4'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 565 due to cloudy percentage (39.8393%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire708', 'creation_timestamp_ms': 1700890832588, 'update_timestamp_ms': 1700891213108, 'start_timestamp_ms': 1700890955168, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.80467414855957, 'id': 'U32GACUVRFJ77IVZRXX4IPTQ', 'name': 'projects/earthengine-legacy/operations/U32GACUVRFJ77IVZRXX4IPTQ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire708', 'creation_timestamp_ms': 1700890833386, 'update_timestamp_ms': 1700891320156, 'start_timestamp_ms': 1700891063507, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.427074432373047, 'id': 'YZPNU2AQLGRHEGX7YPMTOS3T', 'name': 'projects/earthengine-legacy/operations/YZPNU2AQLGRHEGX7YPMTOS3T'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 567 due to cloudy percentage (46.4831%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire710', 'creation_timestamp_ms': 1700891381800, 'update_timestamp_ms': 1700891748421, 'start_timestamp_ms': 1700891487616, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.764047622680664, 'id': 'ERBO42CTU6GYJKOLDRQ2ENXA', 'name': 'projects/earthengine-legacy/operations/ERBO42CTU6GYJKOLDRQ2ENXA'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire710', 'creation_timestamp_ms': 1700891382525, 'update_timestamp_ms': 1700891874541, 'start_timestamp_ms': 1700891593285, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.06446075439453, 'id': 'Q4WZOLPKF6OMXBNJGG34IM6U', 'name': 'projects/earthengine-legacy/operations/Q4WZOLPKF6OMXBNJGG34IM6U'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire711', 'creation_timestamp_ms': 1700891931151, 'update_timestamp_ms': 1700892202761, 'start_timestamp_ms': 1700891938239, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 42.66794967651367, 'id': 'QTI5LMKMV73MYZR6YZB6SFLM', 'name': 'projects/earthengine-legacy/operations/QTI5LMKMV73MYZR6YZB6SFLM'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire711', 'creation_timestamp_ms': 1700891931969, 'update_timestamp_ms': 1700892290770, 'start_timestamp_ms': 1700892032049, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.227800369262695, 'id': 'IYSXU73D2OFR5NHCI6LTPWRU', 'name': 'projects/earthengine-legacy/operations/IYSXU73D2OFR5NHCI6LTPWRU'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire712', 'creation_timestamp_ms': 1700892297391, 'update_timestamp_ms': 1700892568024, 'start_timestamp_ms': 1700892302113, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.228347778320312, 'id': 'HIP4XX4NGC4F2DOXV2NYA3JH', 'name': 'projects/earthengine-legacy/operations/HIP4XX4NGC4F2DOXV2NYA3JH'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire712', 'creation_timestamp_ms': 1700892298102, 'update_timestamp_ms': 1700892764961, 'start_timestamp_ms': 1700892479732, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.688203811645508, 'id': 'WGCN6APASYBZ6FOEEIWNKQLH', 'name': 'projects/earthengine-legacy/operations/WGCN6APASYBZ6FOEEIWNKQLH'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_AfterFire713', 'creation_timestamp_ms': 1700892846287, 'update_timestamp_ms': 1700893133390, 'start_timestamp_ms': 1700892874187, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1zd9Wx7GXqw-w9F4hDZyViF9Rq04K5veI'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.42428207397461, 'id': 'OU2H54MA2PO7KA5YHENRCO6W', 'name': 'projects/earthengine-legacy/operations/OU2H54MA2PO7KA5YHENRCO6W'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_AfterFire713', 'creation_timestamp_ms': 1700892846897, 'update_timestamp_ms': 1700893210466, 'start_timestamp_ms': 1700892949420, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1uXzVETM27x2g-_CYsIfuDMu06lNXe0Rl'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.898141860961914, 'id': 'CD43VGURT5ODOAVDDTFBEB4G', 'name': 'projects/earthengine-legacy/operations/CD43VGURT5ODOAVDDTFBEB4G'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [20], in <cell line: 14>()
#      12     return image.addBands(ndvi)
#      14 for i in num:
#      15     # Set the center point
# ---> 16     point = ee.Geometry.Point(round(dataAfter[i][1], 2), round(dataAfter[i][2], 2))
#      18     # Call an image for the selected point
#      19     tile = ee.ImageCollection('COPERNICUS/S2') \
#      20         .filterBounds(point) \
#      21         .filterDate(dataAfter[i][3], dataAfter[i][4]) \
#      22         .sort('CLOUDY_PIXEL_PERCENTAGE') \
#      23         .first()
#
# IndexError: index 572 is out of bounds for axis 0 with size 572
