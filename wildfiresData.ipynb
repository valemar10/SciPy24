# %% [markdown]
# # Notebook to download Sentinel-2 Satellite GeoTIFF images of forested areas in California before documented wildfires using Google Earth Engine (GEE)
# ## The data points and polygons were gathered from the folowing [Esri Living Atlas Layer ](https://pns.maps.arcgis.com/home/item.html?id=6fd0d8d6f47d414da7bcb1dcd0539999)
# - The layer was preprocessed in ArcGIS Pro:
#     - The layer was filtered to get dates from 2016 because we use sentinel-2 imagery.
#     - The layer was clipped using the Forest Service of the Original Proclaimed National Forest Land layer.
#     - The Feature to point tool was used.
#     - The Get XY point tool was applied.
#     - The final layer attribute table was saved as an excel file "fireForest.xls"
#
# #### Import packages and libraries

# %%
#Import the necessary libraries 
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import pyproj
import warnings
warnings.filterwarnings('ignore')
from shapely.geometry import Point, Polygon
from geopy.distance import great_circle
import ee
import geemap
import numpy as np
import geetools
import time

# %% [markdown]
# ## Code to filter dates to:
# - Use Sentinel-2
# - Change dates outside of the the green up to months from march to september for better results

# %%
# Read the Excel file
excel_file_path = 'ExcelFiles/fireForest.xls'  
df = pd.read_excel(excel_file_path)


# Use the years we know Sentinel was active
mask2 = (df['ALARM_DATE'].dt.year >= 2016)
df = df[mask2]

# Parse date columns to datetime format
df['ALARM_DATE'] = pd.to_datetime(df['ALARM_DATE'], format='%d/%m/%Y', errors='coerce')
df['CONT_DATE'] = pd.to_datetime(df['CONT_DATE'], format='%d/%m/%Y', errors='coerce')
# Define a function to adjust dates
def adjust_dates(row):
    # Specify the updated valid range
    valid_range = range(3, 10)

    # Adjust alarm date to the closest prior date in the range
    if not pd.isna(row['ALARM_DATE']) and row['ALARM_DATE'].month not in valid_range:
        closest_prior_date = row['ALARM_DATE'] - pd.DateOffset(months=row['ALARM_DATE'].month - max(valid_range))
        row['ALARM_DATE'] = closest_prior_date

    # Adjust containment date to the closest later date in the range
    if not pd.isna(row['CONT_DATE']) and row['CONT_DATE'].month not in valid_range:
        closest_later_date = row['CONT_DATE'] + pd.DateOffset(months=min(valid_range) - row['CONT_DATE'].month)
        row['CONT_DATE'] = closest_later_date

    return row

# Apply the function to the DataFrame
df = df.apply(adjust_dates, axis=1)

# %% [markdown]
# ## Code to change NAD83 coordinates to WGS84

# %%
# Define the source and target coordinate systems

source_crs = pyproj.CRS("EPSG:3310")  # NAD 1983 California Albers (Meters)
target_crs = pyproj.CRS("EPSG:4326")  # WGS 84 (EPSG:4326)

# Create a transformer for the coordinate transformation
transformer = pyproj.Transformer.from_crs(source_crs, target_crs, always_xy=True)

# Iterate through rows and transform coordinates
for index, row in df.iterrows():
    x = row['POINT_X']
    y = row['POINT_Y']
    
    # Perform the coordinate transformation
    lon, lat = transformer.transform(x, y)
    
    # Update the DataFrame with transformed coordinates
    df.at[index, 'POINT_X'] = lon
    df.at[index, 'POINT_Y'] = lat

    # Create a mask to filter fires that occurred between March and September

# Save the DataFrame with transformed coordinates to a new Excel file
output_excel_file = 'ExcelFiles/FIRES.xlsx'
df.to_excel(output_excel_file, index=False)

print("Coordinate transformation complete. Output saved to:", output_excel_file)
# Out:
# Coordinate transformation complete. Output saved to: ExcelFiles/FIRES.xlsx

# %% [markdown]
# ## Code to create the desired Regions Of Interests (ROI) to use in GEE
# #### The ROI is created as a square

# %%
# Read the Excel file containing the data
df = pd.read_excel('ExcelFiles/FIRES.xlsx')

# Define the size of the square (miles)
square_side_length_miles = 15

# Create an empty DataFrame to store vertices
vertices_df = pd.DataFrame()

# Function to calculate square vertices and append them to the vertices DataFrame
def calculate_square(row):
    center_lat = row['POINT_Y']  # Latitude from 'POINT_Y'
    center_lon = row['POINT_X']  # Longitude from 'POINT_X'

    # Calculate half of the side length in kilometers
    half_side_length_km = square_side_length_miles * 1.60934  # Convert miles to kilometers

    # Calculate square vertices using great-circle distance
    top_left = great_circle(kilometers=half_side_length_km).destination((center_lat, center_lon), 45)
    top_right = great_circle(kilometers=half_side_length_km).destination((center_lat, center_lon), 135)
    bottom_left = great_circle(kilometers=half_side_length_km).destination((center_lat, center_lon), 315)
    bottom_right = great_circle(kilometers=half_side_length_km).destination((center_lat, center_lon), 225)

    # Create a dictionary with the vertices
    vertices = {
        'y1': top_left.longitude,
        'x1': top_left.latitude,
        'y2': top_right.longitude,
        'x2': top_right.latitude,
        'y3': bottom_right.longitude,
        'x3': bottom_right.latitude,
        'y4': bottom_left.longitude,
        'x4': bottom_left.latitude,
        'y5': center_lon,
        'x5': center_lat  # Include the center point as the fifth vertex
    }

    return pd.Series(vertices)

# Calculate square vertices and append them to the vertices DataFrame
vertices_df = df.apply(calculate_square, axis=1)

# Save the vertices DataFrame to a new Excel file
output_file_path = 'ExcelFiles/output_vertices.xlsx'  
vertices_df.to_excel(output_file_path, index=False, engine='openpyxl')
print(f"Vertices saved to {output_file_path}")
# Out:
# Vertices saved to ExcelFiles/output_vertices.xlsx

# %% [markdown]
# #### Code to check if the ROIs were correctly created

# %%
# Read point data from FIRES.xlsx
point_df = pd.read_excel('ExcelFiles/FIRES.xlsx')

# Read ROI vertices data from output_vertices.xlsx
roi_df = pd.read_excel('ExcelFiles/output_vertices.xlsx')

print(len(roi_df), len(point_df))
# Create Shapely points from point coordinates
points = [Point(xy) for xy in zip(point_df['POINT_Y'], point_df['POINT_X'])]

# Create Shapely polygons from ROI vertices
roi_polygons = [Polygon([(row['x1'], row['y1']), (row['x2'], row['y2']), (row['x3'], row['y3']), (row['x4'], row['y4']), (row['x5'], row['y5'])]) for _, row in roi_df.iterrows()]

# Check if each point is within any of the ROI polygons
within_roi = [any(point.within(roi_polygon) for roi_polygon in roi_polygons) for point in points]

# Add a new column to the point dataframe to indicate if each point is within an ROI
point_df['Within_ROI'] = within_roi

# Save the updated point dataframe to a new Excel file
point_df.to_excel('ExcelFiles/FIRES_with_ROI_status.xlsx', index=False)
print("Point status with respect to ROI saved to ExcelFiles/FIRES_with_ROI_status.xlsx")
# Out:
# 591 591
# Point status with respect to ROI saved to ExcelFiles/FIRES_with_ROI_status.xlsx

# %% [markdown]
# ## Code to create the dates for before and after the fire event to use in GEE
#
# #### Define the times

# %%
import pandas as pd
from datetime import datetime, timedelta

# Read the Excel file
excel_file = 'ExcelFiles/FIRES.xlsx'
df = pd.read_excel(excel_file)

# Ensure columns have meaningful names
df = df.rename(columns={'ALARM_DATE': 'Incident_Date', 'CONT_DATE': 'Containment_Date'})

# Custom function to parse dates and handle invalid dates
def parse_date(date_str):
    try:
        date = pd.to_datetime(date_str)
        if date.year < 1 or date.year > 9999:
            return None  # Invalid year
        return date
    except:
        return None  # Parsing error

# Apply custom date parsing and validation
df['Incident_Date'] = df['Incident_Date'].apply(parse_date)
df['Containment_Date'] = df['Containment_Date'].apply(parse_date)

# Handle invalid dates by setting a default date (adjust as needed)
default_date = datetime(2020, 1, 1)

# Calculate the desired dates to add

df['15_Days_Before_Incident'] = df['Incident_Date'] - timedelta(days=16)
df['1_Day_Before_Incident'] = df['Incident_Date'] - timedelta(days=1)
df['1_Day_After_Containment'] = df['Containment_Date'] + timedelta(days=1)
df['15_Days_After_Containment'] = df['Containment_Date'] + timedelta(days=16)

# Calculate 1 day before the Incident Date

# Replace invalid dates with the default date
df.fillna(default_date, inplace=True)

# Extract the relevant columns
df = df[['15_Days_Before_Incident', '1_Day_Before_Incident', '1_Day_After_Containment', '15_Days_After_Containment', 'Incident_Date', 'Containment_Date']]

# Save the new DataFrame to an Excel file
new_excel_file = 'ExcelFiles/DatesFire.xlsx'
df.to_excel(new_excel_file, index=False)
print(f"The Excel file with the dates has been created: {new_excel_file}")
# Out:
# The Excel file with the dates has been created: ExcelFiles/DatesFire.xlsx

# %% [markdown]
# #### Get the dates into the format needed by GEE

# %%
#Import the data 

dates=pd.read_excel('ExcelFiles/DatesFire.xlsx')


# Define a function to convert the date format
def convert_date_format(date_str):
    try:
        # Parse the input date string
        parsed_date = pd.to_datetime(date_str, format='%d/%m/%Y %I:%M:%S %p')
        # Convert to the desired format 'year-month-day'
        return parsed_date.strftime('%Y-%m-%d')
    except Exception as e:
        # Handle any parsing errors gracefully
        return None

# List of columns to update
columns_to_update = ['15_Days_Before_Incident', '1_Day_Before_Incident', '1_Day_After_Containment', '15_Days_After_Containment', 'Incident_Date', 'Containment_Date']



# Apply the function to the specified columns
for column in columns_to_update:
    dates[column] = dates[column].apply(convert_date_format)

# %% [markdown]
# ## Define and concatenate the arrays needed for GEE

# %%
region_data = pd.read_excel('ExcelFiles/output_vertices.xlsx')

# Read the original Excel file 'FIRES.xlsx'
original_df = pd.read_excel('ExcelFiles/FIRES.xlsx')

# Extract the last two columns
new_df = original_df[['OBJECTID','POINT_X', 'POINT_Y']]

# Save the new DataFrame to a new Excel file
output_file_path = 'ExcelFiles/Point.xlsx'
new_df.to_excel(output_file_path, index=False, engine='openpyxl')
point_data =  pd.read_excel('ExcelFiles/Point.xlsx')

# Concatenate the DataFrames along columns (axis=1)
concatenated_data = pd.concat([point_data, dates, region_data,], axis=1)
data = concatenated_data.values

# %%
new_excel_file = 'ExcelFiles/DataFireFinal.xlsx'
concatenated_data.to_excel(new_excel_file, index=False)

# %% [markdown]
# ## Download the Before Wildfire RGB and NDVI images using GEE
#
# ### Install and authenticate GEE

# %%
#Authenticate 
ee.Authenticate()

#initialize ee
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=OtL-ZEfAobSn89phALpgnALCCgey864O7_pkRfSjFUA&tc=NnBhaqYQx5QPCBXqCOFRwA6UkYCRwsigMAM-SfLrTi8&cc=GOyNJGb2YaiReYQpOvRJQvf36WGZpEA_rMmbtApQ5O4>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=OtL-ZEfAobSn89phALpgnALCCgey864O7_pkRfSjFUA&tc=NnBhaqYQx5QPCBXqCOFRwA6UkYCRwsigMAM-SfLrTi8&cc=GOyNJGb2YaiReYQpOvRJQvf36WGZpEA_rMmbtApQ5O4</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AfJohXlaWMOVkLziyDw0-eaQ0b1zzCOSVq6VOgYLoVPr_xOdIzElErUNzBI
# Successfully saved authorization token.

# %% [markdown]
# ### Export the multiband RGB and NDVI GeoTIFFs (B2, B3, B4, and B8) images for Before the fire event using GEE.

# %%
num = []
for i in range(0, 1000):
    num.append(i)

# Define the bands you want to download
bands_rgb = ['B4', 'B3', 'B2']  # Red, Green, Blue
bands_ndvi = ['B8', 'B4']  # NIR, Red

# Function to calculate NDVI
def calculate_ndvi(image):
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi)

for i in num:
    # Set the center point
    point = ee.Geometry.Point(round(data[i][1], 2), round(data[i][2], 2))

    # Call an image for the selected point
    tile = ee.ImageCollection('COPERNICUS/S2') \
        .filterBounds(point) \
        .filterDate(data[i][3], data[i][4]) \
        .sort('CLOUDY_PIXEL_PERCENTAGE') \
        .first()
    # Check the properties of the image
    image_properties = tile.getInfo()
    cloudy_percentage = image_properties.get('properties', {}).get('CLOUDY_PIXEL_PERCENTAGE', 0)
    if cloudy_percentage <= 10:
        # Define the ROI
        roi = ee.Geometry.Polygon([[
            [data[i][9], data[i][10]],
            [data[i][11], data[i][12]],
            [data[i][13], data[i][14]],
            [data[i][15], data[i][16]],
            [data[i][17], data[i][18]]]])

        # Add NDVI to the selected bands
        tile_with_ndvi = calculate_ndvi(tile)

        # Select RGB and NDVI bands
        rgb_tile = tile.select(bands_rgb)
        ndvi_tile = tile_with_ndvi.select(['NDVI'])

        # Export RGB image to Google Drive
        rgb_task = ee.batch.Export.image.toDrive(**{
            'image': rgb_tile,
            'description': 'RGB_BeforeFire' + str(data[i][0]),
            'folder': 'GEE_FireImagesRGB_before',
            'scale': 10,  # Adjust the scale as needed
            'region': roi.getInfo()['coordinates'],
            'crs': 'EPSG:4326',
            'fileFormat': 'GeoTIFF',
        })
        rgb_task.start()

        # Export NDVI image to Google Drive
        ndvi_task = ee.batch.Export.image.toDrive(**{
            'image': ndvi_tile,
            'description': 'NDVI_BeforeFire' + str(data[i][0]),
            'folder': 'GEE_FireImagesNDVI_before',
            'scale': 10,  # Adjust the scale as needed
            'region': roi.getInfo()['coordinates'],
            'crs': 'EPSG:4326',
            'fileFormat': 'GeoTIFF',
        })
        ndvi_task.start()

        # Wait for the tasks to complete
        while not (rgb_task.status()['state'] in ['COMPLETED', 'FAILED', 'CANCELLED'] and
                   ndvi_task.status()['state'] in ['COMPLETED', 'FAILED', 'CANCELLED']):
            print('RGB Task is', rgb_task.status()['state'])
            print('NDVI Task is', ndvi_task.status()['state'])
            time.sleep(90)  # Wait for 90 seconds before checking again

        # Check the final task statuses
        rgb_task_status = rgb_task.status()
        ndvi_task_status = ndvi_task.status()
        print("RGB Task Status:", rgb_task_status)
        print("NDVI Task Status:", ndvi_task_status)
        print("RGB Task Error Message:", rgb_task_status.get("error_message", "No error message"))
        print("NDVI Task Error Message:", ndvi_task_status.get("error_message", "No error message"))
    else:
        print(f"Skipping image {i} due to cloudy percentage ({cloudy_percentage}%) > 10%")
# Out:
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire621', 'creation_timestamp_ms': 1700883210281, 'update_timestamp_ms': 1700883506721, 'start_timestamp_ms': 1700883217109, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 40.04901123046875, 'id': 'NE6DYBCB4DCGOKZMQJBVZQZR', 'name': 'projects/earthengine-legacy/operations/NE6DYBCB4DCGOKZMQJBVZQZR'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire621', 'creation_timestamp_ms': 1700883210986, 'update_timestamp_ms': 1700883558086, 'start_timestamp_ms': 1700883298086, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.130130767822266, 'id': 'RWHHFBOG36MXJQ3RUSZQOKQT', 'name': 'projects/earthengine-legacy/operations/RWHHFBOG36MXJQ3RUSZQOKQT'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire622', 'creation_timestamp_ms': 1700883576858, 'update_timestamp_ms': 1700883893617, 'start_timestamp_ms': 1700883586605, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.437685012817383, 'id': '3XF43MUV5V4C6B6MELY66CMG', 'name': 'projects/earthengine-legacy/operations/3XF43MUV5V4C6B6MELY66CMG'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire622', 'creation_timestamp_ms': 1700883577769, 'update_timestamp_ms': 1700883878404, 'start_timestamp_ms': 1700883610998, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.773977279663086, 'id': '6XSBFW4RNSKNUMPZJTCDC4WV', 'name': 'projects/earthengine-legacy/operations/6XSBFW4RNSKNUMPZJTCDC4WV'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire623', 'creation_timestamp_ms': 1700883942923, 'update_timestamp_ms': 1700884415398, 'start_timestamp_ms': 1700884157098, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.41095733642578, 'id': '6QYB2NRBJE3XHKOW5ZJKYX55', 'name': 'projects/earthengine-legacy/operations/6QYB2NRBJE3XHKOW5ZJKYX55'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire623', 'creation_timestamp_ms': 1700883943865, 'update_timestamp_ms': 1700884439533, 'start_timestamp_ms': 1700884180561, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.17253494262695, 'id': 'JPBBFVXPCRDPBWV4SWROC5KP', 'name': 'projects/earthengine-legacy/operations/JPBBFVXPCRDPBWV4SWROC5KP'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire624', 'creation_timestamp_ms': 1700884492494, 'update_timestamp_ms': 1700884965430, 'start_timestamp_ms': 1700884687240, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.12070655822754, 'id': '65PSK5PRZIS2CHT3SQE2UCY6', 'name': 'projects/earthengine-legacy/operations/65PSK5PRZIS2CHT3SQE2UCY6'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire624', 'creation_timestamp_ms': 1700884493337, 'update_timestamp_ms': 1700884978476, 'start_timestamp_ms': 1700884713181, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.98335075378418, 'id': 'H2GFCR6BFISLZPMBERUNFTIV', 'name': 'projects/earthengine-legacy/operations/H2GFCR6BFISLZPMBERUNFTIV'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire625', 'creation_timestamp_ms': 1700885042026, 'update_timestamp_ms': 1700885498387, 'start_timestamp_ms': 1700885234679, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 29.46923065185547, 'id': 'PDGCUTLG3KMEL72XSSFFSMQ4', 'name': 'projects/earthengine-legacy/operations/PDGCUTLG3KMEL72XSSFFSMQ4'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire625', 'creation_timestamp_ms': 1700885042704, 'update_timestamp_ms': 1700885502577, 'start_timestamp_ms': 1700885238812, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.278401374816895, 'id': 'CXSBQ4BLATN3QHGTPMRV6SPZ', 'name': 'projects/earthengine-legacy/operations/CXSBQ4BLATN3QHGTPMRV6SPZ'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire626', 'creation_timestamp_ms': 1700885590059, 'update_timestamp_ms': 1700886049033, 'start_timestamp_ms': 1700885770454, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.220670700073242, 'id': 'LD4FVGJDF7K2PWCWBXI5J2IA', 'name': 'projects/earthengine-legacy/operations/LD4FVGJDF7K2PWCWBXI5J2IA'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire626', 'creation_timestamp_ms': 1700885592995, 'update_timestamp_ms': 1700886037897, 'start_timestamp_ms': 1700885776688, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.22887420654297, 'id': 'VHYB4YSZHGUW3BC7FPWJZB5E', 'name': 'projects/earthengine-legacy/operations/VHYB4YSZHGUW3BC7FPWJZB5E'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire627', 'creation_timestamp_ms': 1700886140914, 'update_timestamp_ms': 1700886421048, 'start_timestamp_ms': 1700886152011, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 38.755489349365234, 'id': 'K5HCVYMJLWKB7ZTOY3NTV2FG', 'name': 'projects/earthengine-legacy/operations/K5HCVYMJLWKB7ZTOY3NTV2FG'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire627', 'creation_timestamp_ms': 1700886141525, 'update_timestamp_ms': 1700886593453, 'start_timestamp_ms': 1700886333745, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.706478118896484, 'id': '6UHWLZ7X3DW4GYQX3PQSJEAW', 'name': 'projects/earthengine-legacy/operations/6UHWLZ7X3DW4GYQX3PQSJEAW'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire628', 'creation_timestamp_ms': 1700886599232, 'update_timestamp_ms': 1700886954828, 'start_timestamp_ms': 1700886692673, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.1416130065918, 'id': 'HTYEIVOCW7U3RSGKJ6UWETMT', 'name': 'projects/earthengine-legacy/operations/HTYEIVOCW7U3RSGKJ6UWETMT'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire628', 'creation_timestamp_ms': 1700886600237, 'update_timestamp_ms': 1700887014062, 'start_timestamp_ms': 1700886749808, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.89736557006836, 'id': 'H5HKXAFNALWWSYMGATKRIL6M', 'name': 'projects/earthengine-legacy/operations/H5HKXAFNALWWSYMGATKRIL6M'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire629', 'creation_timestamp_ms': 1700887058487, 'update_timestamp_ms': 1700887427335, 'start_timestamp_ms': 1700887163516, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.96640968322754, 'id': 'MWT72CUI2BBFSYIKMWNFMFHB', 'name': 'projects/earthengine-legacy/operations/MWT72CUI2BBFSYIKMWNFMFHB'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire629', 'creation_timestamp_ms': 1700887059181, 'update_timestamp_ms': 1700887476292, 'start_timestamp_ms': 1700887212649, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.935941696166992, 'id': 'U4VCLUGEUYS3PWMBOTGXASMC', 'name': 'projects/earthengine-legacy/operations/U4VCLUGEUYS3PWMBOTGXASMC'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire630', 'creation_timestamp_ms': 1700887516073, 'update_timestamp_ms': 1700887827536, 'start_timestamp_ms': 1700887549518, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.391263961791992, 'id': 'XMUFNOC7FLTFFRUEMUTCNDJ7', 'name': 'projects/earthengine-legacy/operations/XMUFNOC7FLTFFRUEMUTCNDJ7'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire630', 'creation_timestamp_ms': 1700887516792, 'update_timestamp_ms': 1700887981061, 'start_timestamp_ms': 1700887720350, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.21999740600586, 'id': 'TBXK4Q46CC7HJ56F4ORFN3D5', 'name': 'projects/earthengine-legacy/operations/TBXK4Q46CC7HJ56F4ORFN3D5'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire631', 'creation_timestamp_ms': 1700888067744, 'update_timestamp_ms': 1700888360430, 'start_timestamp_ms': 1700888096898, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.10850524902344, 'id': '4MGA765LD7SMQWW3C37WYYWP', 'name': 'projects/earthengine-legacy/operations/4MGA765LD7SMQWW3C37WYYWP'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire631', 'creation_timestamp_ms': 1700888068798, 'update_timestamp_ms': 1700888401695, 'start_timestamp_ms': 1700888118274, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.749160766601562, 'id': 'XSYCU7QLCETBUIAAG7FSFQD2', 'name': 'projects/earthengine-legacy/operations/XSYCU7QLCETBUIAAG7FSFQD2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire632', 'creation_timestamp_ms': 1700888436701, 'update_timestamp_ms': 1700888775241, 'start_timestamp_ms': 1700888516004, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.57966423034668, 'id': 'A6HKTSSP744JVTNEPC6QHMH2', 'name': 'projects/earthengine-legacy/operations/A6HKTSSP744JVTNEPC6QHMH2'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire632', 'creation_timestamp_ms': 1700888437321, 'update_timestamp_ms': 1700888912962, 'start_timestamp_ms': 1700888670618, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 11.0377836227417, 'id': 'DNGURMAXKOI5Q3MS74LGL2QS', 'name': 'projects/earthengine-legacy/operations/DNGURMAXKOI5Q3MS74LGL2QS'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire633', 'creation_timestamp_ms': 1700888984715, 'update_timestamp_ms': 1700889327034, 'start_timestamp_ms': 1700889066822, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.581012725830078, 'id': 'RN4IJ57IJ5XITOAWOCBPDORO', 'name': 'projects/earthengine-legacy/operations/RN4IJ57IJ5XITOAWOCBPDORO'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire633', 'creation_timestamp_ms': 1700888985387, 'update_timestamp_ms': 1700889503486, 'start_timestamp_ms': 1700889209838, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.631988525390625, 'id': '3J4RLHOBOI5RTZUDRBGEV3XN', 'name': 'projects/earthengine-legacy/operations/3J4RLHOBOI5RTZUDRBGEV3XN'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire634', 'creation_timestamp_ms': 1700889533867, 'update_timestamp_ms': 1700889854322, 'start_timestamp_ms': 1700889599378, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.517995834350586, 'id': 'Y3INQS2CT2UIWFITESDESSXI', 'name': 'projects/earthengine-legacy/operations/Y3INQS2CT2UIWFITESDESSXI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire634', 'creation_timestamp_ms': 1700889534545, 'update_timestamp_ms': 1700890015060, 'start_timestamp_ms': 1700889772172, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 14.071310043334961, 'id': 'Y7QJVYSDLJDAWV5T362XU4G2', 'name': 'projects/earthengine-legacy/operations/Y7QJVYSDLJDAWV5T362XU4G2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire635', 'creation_timestamp_ms': 1700890082821, 'update_timestamp_ms': 1700890394439, 'start_timestamp_ms': 1700890136833, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 36.76859664916992, 'id': 'GXVMD6QD3LT2THMETZNOK7VJ', 'name': 'projects/earthengine-legacy/operations/GXVMD6QD3LT2THMETZNOK7VJ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire635', 'creation_timestamp_ms': 1700890083356, 'update_timestamp_ms': 1700890552948, 'start_timestamp_ms': 1700890292403, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.58169937133789, 'id': 'M2Y4Q3QGSH32UR3PIXN2K37X', 'name': 'projects/earthengine-legacy/operations/M2Y4Q3QGSH32UR3PIXN2K37X'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire636', 'creation_timestamp_ms': 1700890632143, 'update_timestamp_ms': 1700890951599, 'start_timestamp_ms': 1700890675174, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.828529357910156, 'id': 'XUIQUVAQPWNXBTWIT56DRQBE', 'name': 'projects/earthengine-legacy/operations/XUIQUVAQPWNXBTWIT56DRQBE'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire636', 'creation_timestamp_ms': 1700890633682, 'update_timestamp_ms': 1700891088798, 'start_timestamp_ms': 1700890826347, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.540756225585938, 'id': 'L5LE7MYDN3YR4EOHYZCFV34Y', 'name': 'projects/earthengine-legacy/operations/L5LE7MYDN3YR4EOHYZCFV34Y'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire637', 'creation_timestamp_ms': 1700891181184, 'update_timestamp_ms': 1700891479769, 'start_timestamp_ms': 1700891220435, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.15089225769043, 'id': 'MNWY7UKSQMX6QWZGUC6WHD66', 'name': 'projects/earthengine-legacy/operations/MNWY7UKSQMX6QWZGUC6WHD66'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire637', 'creation_timestamp_ms': 1700891181804, 'update_timestamp_ms': 1700891586074, 'start_timestamp_ms': 1700891327428, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 20.577125549316406, 'id': 'YQVY2G4HEUOZAOIY4XIB4QEG', 'name': 'projects/earthengine-legacy/operations/YQVY2G4HEUOZAOIY4XIB4QEG'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire638', 'creation_timestamp_ms': 1700891639437, 'update_timestamp_ms': 1700891980043, 'start_timestamp_ms': 1700891723559, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.56496810913086, 'id': 'GA65UUUKAI53BAXYL7KXFWW7', 'name': 'projects/earthengine-legacy/operations/GA65UUUKAI53BAXYL7KXFWW7'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire638', 'creation_timestamp_ms': 1700891640222, 'update_timestamp_ms': 1700892024161, 'start_timestamp_ms': 1700891763756, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.44291114807129, 'id': 'GPJD5FCTI7Q3RZKEOIK3YAYC', 'name': 'projects/earthengine-legacy/operations/GPJD5FCTI7Q3RZKEOIK3YAYC'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire639', 'creation_timestamp_ms': 1700892096935, 'update_timestamp_ms': 1700892471686, 'start_timestamp_ms': 1700892207873, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.655349731445312, 'id': 'ZPIDKKISNCIR7XMLMKEFDWR4', 'name': 'projects/earthengine-legacy/operations/ZPIDKKISNCIR7XMLMKEFDWR4'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire639', 'creation_timestamp_ms': 1700892097784, 'update_timestamp_ms': 1700892555230, 'start_timestamp_ms': 1700892291344, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.129573822021484, 'id': '2UBPMDFDAOCBJULQIYHAVOOR', 'name': 'projects/earthengine-legacy/operations/2UBPMDFDAOCBJULQIYHAVOOR'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire640', 'creation_timestamp_ms': 1700892665396, 'update_timestamp_ms': 1700892928508, 'start_timestamp_ms': 1700892670059, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.70313262939453, 'id': 'AJZ3HX3HL65T5RMOYSN4PFP5', 'name': 'projects/earthengine-legacy/operations/AJZ3HX3HL65T5RMOYSN4PFP5'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire640', 'creation_timestamp_ms': 1700892666034, 'update_timestamp_ms': 1700892962384, 'start_timestamp_ms': 1700892702212, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.250574111938477, 'id': 'AHJ7HL4YHJQSGSKFJEX4ORZZ', 'name': 'projects/earthengine-legacy/operations/AHJ7HL4YHJQSGSKFJEX4ORZZ'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire641', 'creation_timestamp_ms': 1700893031754, 'update_timestamp_ms': 1700893325019, 'start_timestamp_ms': 1700893061366, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.023780822753906, 'id': 'ASL5TQXVSPKGOQO35MU5EGPP', 'name': 'projects/earthengine-legacy/operations/ASL5TQXVSPKGOQO35MU5EGPP'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire641', 'creation_timestamp_ms': 1700893032340, 'update_timestamp_ms': 1700893404485, 'start_timestamp_ms': 1700893139792, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 30.415109634399414, 'id': 'AVK4IQS6SSP44YBZV6MLIODV', 'name': 'projects/earthengine-legacy/operations/AVK4IQS6SSP44YBZV6MLIODV'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire642', 'creation_timestamp_ms': 1700893489111, 'update_timestamp_ms': 1700893777178, 'start_timestamp_ms': 1700893493603, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 36.855953216552734, 'id': 'NFS73FISF2KS75SVOLXETPQH', 'name': 'projects/earthengine-legacy/operations/NFS73FISF2KS75SVOLXETPQH'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire642', 'creation_timestamp_ms': 1700893489743, 'update_timestamp_ms': 1700893756815, 'start_timestamp_ms': 1700893497644, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 16.20657730102539, 'id': 'PGCPATBYWDNLTIRTZG4FT7HY', 'name': 'projects/earthengine-legacy/operations/PGCPATBYWDNLTIRTZG4FT7HY'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire643', 'creation_timestamp_ms': 1700893859838, 'update_timestamp_ms': 1700894119750, 'start_timestamp_ms': 1700893864937, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.817781448364258, 'id': 'C724GBYKY6CENBXVVZCCIKHQ', 'name': 'projects/earthengine-legacy/operations/C724GBYKY6CENBXVVZCCIKHQ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire643', 'creation_timestamp_ms': 1700893860469, 'update_timestamp_ms': 1700894117305, 'start_timestamp_ms': 1700893864941, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 10.753581047058105, 'id': 'NHAQASTQFIS3AJRLIWNAK2LE', 'name': 'projects/earthengine-legacy/operations/NHAQASTQFIS3AJRLIWNAK2LE'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire644', 'creation_timestamp_ms': 1700894134795, 'update_timestamp_ms': 1700894399884, 'start_timestamp_ms': 1700894139219, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.159942626953125, 'id': 'XLQQXWKXAMJPZO2P6POZZ7OI', 'name': 'projects/earthengine-legacy/operations/XLQQXWKXAMJPZO2P6POZZ7OI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire644', 'creation_timestamp_ms': 1700894135351, 'update_timestamp_ms': 1700894406543, 'start_timestamp_ms': 1700894149004, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.997922897338867, 'id': '5HPNRSJAK4YAHE7CPSMHK4A7', 'name': 'projects/earthengine-legacy/operations/5HPNRSJAK4YAHE7CPSMHK4A7'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire645', 'creation_timestamp_ms': 1700894409482, 'update_timestamp_ms': 1700894673327, 'start_timestamp_ms': 1700894416274, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 29.990209579467773, 'id': 'MVKLMWR4JLJECVLEXQNIDMKI', 'name': 'projects/earthengine-legacy/operations/MVKLMWR4JLJECVLEXQNIDMKI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire645', 'creation_timestamp_ms': 1700894410048, 'update_timestamp_ms': 1700894660261, 'start_timestamp_ms': 1700894416270, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.912076950073242, 'id': 'JZWVXMUJ6YGQRHRXAGKFRZLE', 'name': 'projects/earthengine-legacy/operations/JZWVXMUJ6YGQRHRXAGKFRZLE'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire646', 'creation_timestamp_ms': 1700894684399, 'update_timestamp_ms': 1700894959474, 'start_timestamp_ms': 1700894689462, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 38.873653411865234, 'id': 'XBRWWI4NX52EM3OQRQ6PBHNA', 'name': 'projects/earthengine-legacy/operations/XBRWWI4NX52EM3OQRQ6PBHNA'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire646', 'creation_timestamp_ms': 1700894685316, 'update_timestamp_ms': 1700894955719, 'start_timestamp_ms': 1700894689461, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.94491958618164, 'id': 'W7CKP4LUZNGFPI7OMFLKUUIJ', 'name': 'projects/earthengine-legacy/operations/W7CKP4LUZNGFPI7OMFLKUUIJ'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire647', 'creation_timestamp_ms': 1700895051088, 'update_timestamp_ms': 1700895312865, 'start_timestamp_ms': 1700895056913, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.569568634033203, 'id': 'GYRBPXA6CBYYPUH332Y5IDNX', 'name': 'projects/earthengine-legacy/operations/GYRBPXA6CBYYPUH332Y5IDNX'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire647', 'creation_timestamp_ms': 1700895051789, 'update_timestamp_ms': 1700895312083, 'start_timestamp_ms': 1700895056911, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.99201202392578, 'id': '4PLMZI6TXE6QM7MD6KF7VH7Z', 'name': 'projects/earthengine-legacy/operations/4PLMZI6TXE6QM7MD6KF7VH7Z'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire648', 'creation_timestamp_ms': 1700895326486, 'update_timestamp_ms': 1700895604196, 'start_timestamp_ms': 1700895331598, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 26.57587432861328, 'id': 'JPGEOYTYCJ3RTGAAAWLCMSC3', 'name': 'projects/earthengine-legacy/operations/JPGEOYTYCJ3RTGAAAWLCMSC3'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire648', 'creation_timestamp_ms': 1700895327178, 'update_timestamp_ms': 1700895592413, 'start_timestamp_ms': 1700895331597, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.04625701904297, 'id': 'DE75TT53WUV42OXE73E2GPVI', 'name': 'projects/earthengine-legacy/operations/DE75TT53WUV42OXE73E2GPVI'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire649', 'creation_timestamp_ms': 1700895692968, 'update_timestamp_ms': 1700895958747, 'start_timestamp_ms': 1700895700500, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.490360260009766, 'id': 'LGF6ICWAJDYKMXQRMJLTOQI5', 'name': 'projects/earthengine-legacy/operations/LGF6ICWAJDYKMXQRMJLTOQI5'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire649', 'creation_timestamp_ms': 1700895693617, 'update_timestamp_ms': 1700895955814, 'start_timestamp_ms': 1700895700499, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.31727409362793, 'id': 'S6ESJULAMEAWCZC45FFDF4VR', 'name': 'projects/earthengine-legacy/operations/S6ESJULAMEAWCZC45FFDF4VR'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire650', 'creation_timestamp_ms': 1700895968260, 'update_timestamp_ms': 1700896274266, 'start_timestamp_ms': 1700895976155, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 47.2008171081543, 'id': 'G6GP2SN2IYTP4CGV3L62ZQSQ', 'name': 'projects/earthengine-legacy/operations/G6GP2SN2IYTP4CGV3L62ZQSQ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire650', 'creation_timestamp_ms': 1700895968912, 'update_timestamp_ms': 1700896265599, 'start_timestamp_ms': 1700895976152, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.48978614807129, 'id': '6QBUVEMP2SYARII2PBMYUWQG', 'name': 'projects/earthengine-legacy/operations/6QBUVEMP2SYARII2PBMYUWQG'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire651', 'creation_timestamp_ms': 1700896334797, 'update_timestamp_ms': 1700896602640, 'start_timestamp_ms': 1700896340993, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 25.0069580078125, 'id': 'NJJHABPQWZICLQ4KAJ6BSEYJ', 'name': 'projects/earthengine-legacy/operations/NJJHABPQWZICLQ4KAJ6BSEYJ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire651', 'creation_timestamp_ms': 1700896335469, 'update_timestamp_ms': 1700896639655, 'start_timestamp_ms': 1700896340993, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 37.26702117919922, 'id': 'WQEMGL43T7BCIPHEOJKPTCSI', 'name': 'projects/earthengine-legacy/operations/WQEMGL43T7BCIPHEOJKPTCSI'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire652', 'creation_timestamp_ms': 1700896701449, 'update_timestamp_ms': 1700896965365, 'start_timestamp_ms': 1700896704544, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.960891723632812, 'id': '7MCZGBJL3HEHL3HBW25GICTV', 'name': 'projects/earthengine-legacy/operations/7MCZGBJL3HEHL3HBW25GICTV'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire652', 'creation_timestamp_ms': 1700896702080, 'update_timestamp_ms': 1700896952507, 'start_timestamp_ms': 1700896707849, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 23.2451171875, 'id': 'MG3GMNLU2ENHOTO5WJJPUDET', 'name': 'projects/earthengine-legacy/operations/MG3GMNLU2ENHOTO5WJJPUDET'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 530 due to cloudy percentage (20.9746%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire654', 'creation_timestamp_ms': 1700896977029, 'update_timestamp_ms': 1700897247175, 'start_timestamp_ms': 1700896987460, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.148033142089844, 'id': '2ZQRFAQMFSXTOK4HQ3YGAE3L', 'name': 'projects/earthengine-legacy/operations/2ZQRFAQMFSXTOK4HQ3YGAE3L'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire654', 'creation_timestamp_ms': 1700896977933, 'update_timestamp_ms': 1700897249171, 'start_timestamp_ms': 1700896987458, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.768356323242188, 'id': 'UTFBFIAZJCGHZI2PYG5XKLQ4', 'name': 'projects/earthengine-legacy/operations/UTFBFIAZJCGHZI2PYG5XKLQ4'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire655', 'creation_timestamp_ms': 1700897252102, 'update_timestamp_ms': 1700897533298, 'start_timestamp_ms': 1700897258559, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 35.005226135253906, 'id': 'Q7ETHO3S2VGOMRYG3NQH3YN5', 'name': 'projects/earthengine-legacy/operations/Q7ETHO3S2VGOMRYG3NQH3YN5'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire655', 'creation_timestamp_ms': 1700897252911, 'update_timestamp_ms': 1700897523095, 'start_timestamp_ms': 1700897258562, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 39.72978210449219, 'id': 'XBQMBH3ZQUYYMBVXZKJBFW72', 'name': 'projects/earthengine-legacy/operations/XBQMBH3ZQUYYMBVXZKJBFW72'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire656', 'creation_timestamp_ms': 1700897621604, 'update_timestamp_ms': 1700897893195, 'start_timestamp_ms': 1700897632458, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 29.974027633666992, 'id': 'KHO3DJ5OWSUSCXE5BEZCIVNL', 'name': 'projects/earthengine-legacy/operations/KHO3DJ5OWSUSCXE5BEZCIVNL'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire656', 'creation_timestamp_ms': 1700897622250, 'update_timestamp_ms': 1700897891533, 'start_timestamp_ms': 1700897632457, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.818635940551758, 'id': 'NAOFKYL2XLNGZBMSOV3X6SC6', 'name': 'projects/earthengine-legacy/operations/NAOFKYL2XLNGZBMSOV3X6SC6'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire657', 'creation_timestamp_ms': 1700897897514, 'update_timestamp_ms': 1700898161804, 'start_timestamp_ms': 1700897903434, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.328340530395508, 'id': 'FL4YAOL53QEHJSR53KCBENGP', 'name': 'projects/earthengine-legacy/operations/FL4YAOL53QEHJSR53KCBENGP'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire657', 'creation_timestamp_ms': 1700897898132, 'update_timestamp_ms': 1700898147088, 'start_timestamp_ms': 1700897903434, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.44744300842285, 'id': 'DDCF2LFJP67JIJ5FJGAHNORL', 'name': 'projects/earthengine-legacy/operations/DDCF2LFJP67JIJ5FJGAHNORL'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 535 due to cloudy percentage (12.7655%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire659', 'creation_timestamp_ms': 1700898173578, 'update_timestamp_ms': 1700898458809, 'start_timestamp_ms': 1700898180498, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 32.75896453857422, 'id': 'RGPDQ2BW3MJMTDTPIC2BNZGZ', 'name': 'projects/earthengine-legacy/operations/RGPDQ2BW3MJMTDTPIC2BNZGZ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire659', 'creation_timestamp_ms': 1700898174306, 'update_timestamp_ms': 1700898437940, 'start_timestamp_ms': 1700898180497, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.753623962402344, 'id': '42ARCYHEOK3EOZHUMTGOOLPV', 'name': 'projects/earthengine-legacy/operations/42ARCYHEOK3EOZHUMTGOOLPV'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire660', 'creation_timestamp_ms': 1700898540137, 'update_timestamp_ms': 1700898810965, 'start_timestamp_ms': 1700898546327, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 28.184858322143555, 'id': '6MX5YVFZDTXEKQNAMP6SA6FJ', 'name': 'projects/earthengine-legacy/operations/6MX5YVFZDTXEKQNAMP6SA6FJ'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire660', 'creation_timestamp_ms': 1700898541068, 'update_timestamp_ms': 1700898805342, 'start_timestamp_ms': 1700898546327, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.778457641601562, 'id': 'XKVBERDH2UWEUWPQPU2LNXN7', 'name': 'projects/earthengine-legacy/operations/XKVBERDH2UWEUWPQPU2LNXN7'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire661', 'creation_timestamp_ms': 1700898816197, 'update_timestamp_ms': 1700899083124, 'start_timestamp_ms': 1700898822437, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 29.983427047729492, 'id': 'YKZAZT4OLHZVJZ7VUXZAJ44Q', 'name': 'projects/earthengine-legacy/operations/YKZAZT4OLHZVJZ7VUXZAJ44Q'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire661', 'creation_timestamp_ms': 1700898816905, 'update_timestamp_ms': 1700899080864, 'start_timestamp_ms': 1700898822436, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 19.61947250366211, 'id': 'VYVNP7BHHXWULRN5RGP4EDCM', 'name': 'projects/earthengine-legacy/operations/VYVNP7BHHXWULRN5RGP4EDCM'}
# ...
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire700', 'creation_timestamp_ms': 1700911495381, 'update_timestamp_ms': 1700911757858, 'start_timestamp_ms': 1700911501584, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.60604476928711, 'id': 'EF46QV5GMQXU3OALFKQ4QENW', 'name': 'projects/earthengine-legacy/operations/EF46QV5GMQXU3OALFKQ4QENW'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire701', 'creation_timestamp_ms': 1700911775424, 'update_timestamp_ms': 1700912048607, 'start_timestamp_ms': 1700911785746, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.716754913330078, 'id': '4M5UBLDQRNKI732AHHF3M6S4', 'name': 'projects/earthengine-legacy/operations/4M5UBLDQRNKI732AHHF3M6S4'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire701', 'creation_timestamp_ms': 1700911776038, 'update_timestamp_ms': 1700912042575, 'start_timestamp_ms': 1700911785743, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 12.642870903015137, 'id': 'D7MXLS4J3MK5MV57C5DI3OWO', 'name': 'projects/earthengine-legacy/operations/D7MXLS4J3MK5MV57C5DI3OWO'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# Skipping image 579 due to cloudy percentage (13.0295%) > 10%
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire703', 'creation_timestamp_ms': 1700912053895, 'update_timestamp_ms': 1700912319915, 'start_timestamp_ms': 1700912058894, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 22.02785873413086, 'id': 'AMHEVOU5KBZWJOLR457ND54J', 'name': 'projects/earthengine-legacy/operations/AMHEVOU5KBZWJOLR457ND54J'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire703', 'creation_timestamp_ms': 1700912054457, 'update_timestamp_ms': 1700912318123, 'start_timestamp_ms': 1700912058893, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.264720916748047, 'id': '36Y4MT3VDLLNJ2ELO3WIXKSY', 'name': 'projects/earthengine-legacy/operations/36Y4MT3VDLLNJ2ELO3WIXKSY'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire704', 'creation_timestamp_ms': 1700912328926, 'update_timestamp_ms': 1700912616723, 'start_timestamp_ms': 1700912332955, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 37.892295837402344, 'id': 'IKR7UHJIT4FWD73MP7LXANUE', 'name': 'projects/earthengine-legacy/operations/IKR7UHJIT4FWD73MP7LXANUE'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire704', 'creation_timestamp_ms': 1700912329551, 'update_timestamp_ms': 1700912605722, 'start_timestamp_ms': 1700912341673, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 17.980945587158203, 'id': '7M5AOAD6QZTYDSLH2YTCPEIP', 'name': 'projects/earthengine-legacy/operations/7M5AOAD6QZTYDSLH2YTCPEIP'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire705', 'creation_timestamp_ms': 1700912695330, 'update_timestamp_ms': 1700912996444, 'start_timestamp_ms': 1700912700431, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 41.64474868774414, 'id': 'Z3VFKPLZ3GDKBHBWFBC6CIV7', 'name': 'projects/earthengine-legacy/operations/Z3VFKPLZ3GDKBHBWFBC6CIV7'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire705', 'creation_timestamp_ms': 1700912696042, 'update_timestamp_ms': 1700912968655, 'start_timestamp_ms': 1700912700429, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.647445678710938, 'id': 'G2ZTZD36GL723CC5KI5FKM62', 'name': 'projects/earthengine-legacy/operations/G2ZTZD36GL723CC5KI5FKM62'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire706', 'creation_timestamp_ms': 1700913061638, 'update_timestamp_ms': 1700913346113, 'start_timestamp_ms': 1700913068519, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 37.537662506103516, 'id': 'DJWHHFFXV7ANOM5LGGHX6A2U', 'name': 'projects/earthengine-legacy/operations/DJWHHFFXV7ANOM5LGGHX6A2U'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire706', 'creation_timestamp_ms': 1700913062506, 'update_timestamp_ms': 1700913350544, 'start_timestamp_ms': 1700913068521, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.75469207763672, 'id': 'WGO4ZRXRMVS2LFX3WM2BKZUL', 'name': 'projects/earthengine-legacy/operations/WGO4ZRXRMVS2LFX3WM2BKZUL'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is COMPLETED
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire707', 'creation_timestamp_ms': 1700913428272, 'update_timestamp_ms': 1700913701437, 'start_timestamp_ms': 1700913433855, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 24.155908584594727, 'id': 'X7TVIBXYNFAK52PW6LPIM55V', 'name': 'projects/earthengine-legacy/operations/X7TVIBXYNFAK52PW6LPIM55V'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire707', 'creation_timestamp_ms': 1700913429189, 'update_timestamp_ms': 1700913719487, 'start_timestamp_ms': 1700913433857, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 35.14649200439453, 'id': 'CHYNKJ2H4WGOASO2QPSDJR3J', 'name': 'projects/earthengine-legacy/operations/CHYNKJ2H4WGOASO2QPSDJR3J'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire708', 'creation_timestamp_ms': 1700913797312, 'update_timestamp_ms': 1700914064205, 'start_timestamp_ms': 1700913803424, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 33.71635818481445, 'id': 'OPOIPPMTZYB3IWJLLHXDSAN6', 'name': 'projects/earthengine-legacy/operations/OPOIPPMTZYB3IWJLLHXDSAN6'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire708', 'creation_timestamp_ms': 1700913798133, 'update_timestamp_ms': 1700914059433, 'start_timestamp_ms': 1700913803424, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 16.943708419799805, 'id': 'ZXED6SIJ4VYF2BGYM6R2QTSJ', 'name': 'projects/earthengine-legacy/operations/ZXED6SIJ4VYF2BGYM6R2QTSJ'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire709', 'creation_timestamp_ms': 1700914075062, 'update_timestamp_ms': 1700914378406, 'start_timestamp_ms': 1700914079914, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 42.69953155517578, 'id': 'TTEBBOILIRT3MSISKF2OAI7E', 'name': 'projects/earthengine-legacy/operations/TTEBBOILIRT3MSISKF2OAI7E'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire709', 'creation_timestamp_ms': 1700914076010, 'update_timestamp_ms': 1700914381327, 'start_timestamp_ms': 1700914079913, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 27.035106658935547, 'id': '3ZOVS7QVDEPGMQQM2Z6WLUF2', 'name': 'projects/earthengine-legacy/operations/3ZOVS7QVDEPGMQQM2Z6WLUF2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire710', 'creation_timestamp_ms': 1700914444512, 'update_timestamp_ms': 1700914733577, 'start_timestamp_ms': 1700914450859, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 30.27040672302246, 'id': 'EWZN4QJUCUEYS75WCKFKKH5N', 'name': 'projects/earthengine-legacy/operations/EWZN4QJUCUEYS75WCKFKKH5N'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire710', 'creation_timestamp_ms': 1700914445164, 'update_timestamp_ms': 1700914730735, 'start_timestamp_ms': 1700914450862, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 21.36264419555664, 'id': 'XULTMKLH57DTX4V64IIKZWM2', 'name': 'projects/earthengine-legacy/operations/XULTMKLH57DTX4V64IIKZWM2'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is COMPLETED
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire711', 'creation_timestamp_ms': 1700914811014, 'update_timestamp_ms': 1700915094108, 'start_timestamp_ms': 1700914819106, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 34.92354965209961, 'id': '5LMW2RSV7GB4XI5XW3OEKHDI', 'name': 'projects/earthengine-legacy/operations/5LMW2RSV7GB4XI5XW3OEKHDI'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire711', 'creation_timestamp_ms': 1700914811624, 'update_timestamp_ms': 1700915082624, 'start_timestamp_ms': 1700914819107, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 18.9282283782959, 'id': 'GSTFVSXUPFRJI3KX2HZJ52GW', 'name': 'projects/earthengine-legacy/operations/GSTFVSXUPFRJI3KX2HZJ52GW'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire712', 'creation_timestamp_ms': 1700915177234, 'update_timestamp_ms': 1700915462612, 'start_timestamp_ms': 1700915183181, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 38.96617126464844, 'id': '5THQDEIXKH5C6CT4NUBYJJK7', 'name': 'projects/earthengine-legacy/operations/5THQDEIXKH5C6CT4NUBYJJK7'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire712', 'creation_timestamp_ms': 1700915177860, 'update_timestamp_ms': 1700915490287, 'start_timestamp_ms': 1700915183183, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 37.81804656982422, 'id': 'DMDG5WUBIHF4T5GKE7FV24XW', 'name': 'projects/earthengine-legacy/operations/DMDG5WUBIHF4T5GKE7FV24XW'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# RGB Task is READY
# NDVI Task is READY
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task is RUNNING
# NDVI Task is RUNNING
# RGB Task Status: {'state': 'COMPLETED', 'description': 'RGB_BeforeFire713', 'creation_timestamp_ms': 1700915543778, 'update_timestamp_ms': 1700915812941, 'start_timestamp_ms': 1700915550983, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1k4rzxlY5lh0NbxBdidO50vf8cpjLlJXf'], 'attempt': 1, 'batch_eecu_usage_seconds': 41.682594299316406, 'id': 'DXQPY3XLA7OK3HRRIPCW3NYR', 'name': 'projects/earthengine-legacy/operations/DXQPY3XLA7OK3HRRIPCW3NYR'}
# NDVI Task Status: {'state': 'COMPLETED', 'description': 'NDVI_BeforeFire713', 'creation_timestamp_ms': 1700915544408, 'update_timestamp_ms': 1700915794609, 'start_timestamp_ms': 1700915550981, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/1c1vcS-WWjBZ6WNSWMbW6-vaM3X95jT-_'], 'attempt': 1, 'batch_eecu_usage_seconds': 15.662397384643555, 'id': 'ACZ34GXE3FRM3Z6632HGLM3C', 'name': 'projects/earthengine-legacy/operations/ACZ34GXE3FRM3Z6632HGLM3C'}
# RGB Task Error Message: No error message
# NDVI Task Error Message: No error message
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [14], in <cell line: 14>()
#      12     return image.addBands(ndvi)
#      14 for i in num:
#      15     # Set the center point
# ---> 16     point = ee.Geometry.Point(round(data[i][1], 2), round(data[i][2], 2))
#      18     # Call an image for the selected point
#      19     tile = ee.ImageCollection('COPERNICUS/S2') \
#      20         .filterBounds(point) \
#      21         .filterDate(data[i][3], data[i][4]) \
#      22         .sort('CLOUDY_PIXEL_PERCENTAGE') \
#      23         .first()
#
# IndexError: index 591 is out of bounds for axis 0 with size 591
